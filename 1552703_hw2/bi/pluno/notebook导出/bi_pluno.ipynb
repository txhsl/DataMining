# %%
# PrefixSpan

import sys
import pandas as pd
import numpy as np

PLACE_HOLDER = '_'

def input():

    # file input
    data = pd.read_csv('trade.csv', usecols=['uid', 'vipno', 'sldat', 'pluno'])
    data['timestamp'] = pd.to_datetime(data['sldat'])

    # sort 
    data.sort_values(['vipno','timestamp'],ascending=[1,1],inplace=True) 

    # make groups 
    data['rank'] = data['timestamp'].groupby(data['vipno']).rank(ascending=0,method='first')

    # take top 60% in every group
    grouped = data.groupby(['vipno'], as_index = True).apply(lambda x: x[x['rank'] <= (0.6 * x['rank'].max())])

    # convert
    data_set = grouped.drop(['rank', 'timestamp', 'sldat', 'vipno'], axis=1).reset_index(drop=True)

    # merge by uid
    data_set['value'] = data_set['pluno']
    data_set = data_set.pivot_table(data_set, index=['uid'], columns=['pluno'])

    return data_set.fillna(0)

def input_new():

    # file input
    data = pd.read_csv('trade_new.csv', usecols=['uid', 'vipno', 'sldatime', 'pluno'])
    data['timestamp'] = pd.to_datetime(data['sldatime'])

    # sort 
    data.sort_values(['vipno','timestamp'],ascending=[1,1],inplace=True) 

    # make groups 
    data['rank'] = data['timestamp'].groupby(data['vipno']).rank(ascending=0,method='first')

    # take top 60% in every group
    grouped = data.groupby(['vipno'], as_index = True).apply(lambda x: x[x['rank'] <= (0.6 * x['rank'].max())])

    # convert
    data_set = grouped.drop(['rank', 'timestamp', 'sldatime', 'vipno'], axis=1).reset_index(drop=True)

    # merge by uid
    data_set['value'] = data_set['pluno']
    data_set = data_set.pivot_table(data_set, index=['uid'], columns=['pluno'])

    return data_set.fillna(0)

def createInitSet(data_set):  

    # clear all 0
    data_array = data_set.as_matrix()
    data_dok = []
    for row in data_array:
        s = []
        s.append([str(x) for x in row if x != 0.0])
        data_dok.append(s)

    return data_dok

# %%
class SquencePattern:
    def __init__(self, squence, support):
        self.squence = []
        for s in squence:
            self.squence.append(list(s))
        self.support = support

    def append(self, p):
        if p.squence[0][0] == PLACE_HOLDER:
            first_e = p.squence[0]
            first_e.remove(PLACE_HOLDER)
            self.squence[-1].extend(first_e)
            self.squence.extend(p.squence[1:])
        else:
            self.squence.extend(p.squence)
        self.support = min(self.support, p.support)


def prefixSpan(pattern, S, threshold):
    patterns = []
    f_list = frequent_items(S, pattern, threshold)
	
    for i in f_list:
        p = SquencePattern(pattern.squence, pattern.support)
        p.append(i)
        patterns.append(p)
        
        
        p_S = build_projected_database(S, p)
        p_patterns = prefixSpan(p, p_S, threshold)
        patterns.extend(p_patterns)
    return patterns


def frequent_items(S, pattern, threshold):
    items = {}
    _items = {}
    f_list = []
    if S is None or len(S) == 0:
        return []

    if len(pattern.squence) != 0:
        last_e = pattern.squence[-1]
    else:
        last_e = []
    for s in S:
        #class 1
        is_prefix = True
        for item in last_e:
            if item not in s[0]:
                is_prefix = False
                break
        if is_prefix and len(last_e) > 0:
            index = s[0].index(last_e[-1])
            if index < len(s[0]) - 1:
                for item in s[0][index + 1:]:
                    if item in _items:
                        _items[item] += 1
                    else:
                        _items[item] = 1

        #class 2
        if PLACE_HOLDER in s[0]:
            for item in s[0][1:]:
                if item in _items:
                    _items[item] += 1
                else:
                    _items[item] = 1
            s = s[1:]

        #class 3
        counted = []
        for element in s:
            for item in element:
                if item not in counted:
                    counted.append(item)
                    if item in items:
                        items[item] += 1
                    else:
                        items[item] = 1

    f_list.extend([SquencePattern([[PLACE_HOLDER, k]], v)
                    for k, v in _items.iteritems()
                    if v >= threshold])
    f_list.extend([SquencePattern([[k]], v)
                   for k, v in items.iteritems()
                   if v >= threshold])
    sorted_list = sorted(f_list, key=lambda p: p.support)
    return sorted_list  
    


def build_projected_database(S, pattern):
    """
    suppose S is projected database base on pattern's prefix,
    so we only need to use the last element in pattern to
    build projected database
    """
    p_S = []
    last_e = pattern.squence[-1]
    last_item = last_e[-1]
    for s in S:
        p_s = []
        for element in s:
            is_prefix = False
            if PLACE_HOLDER in element:
                if last_item in element and len(pattern.squence[-1]) > 1:
                    is_prefix = True
            else:
                is_prefix = True
                for item in last_e:
                    if item not in element:
                        is_prefix = False
                        break

            if is_prefix:
                e_index = s.index(element)
                i_index = element.index(last_item)
                if i_index == len(element) - 1:
                    p_s = s[e_index + 1:]
                else:
                    p_s = s[e_index:]
                    index = element.index(last_item)
                    e = element[i_index:]
                    e[0] = PLACE_HOLDER
                    p_s[0] = e
                break
        if len(p_s) != 0:
            p_S.append(p_s)

    return p_S


def print_patterns(patterns):
    for p in patterns:
        print("pattern:{0}, support:{1}".format(p.squence, p.support))

# %%
if __name__ == "__main__":
    
    S = createInitSet(input())

    for min_support in [2,4,8,16,32,64]:
        print "\nmin_support = %d: "%min_support
        patterns = prefixSpan(SquencePattern([], sys.maxint), S, min_support)
        print_patterns(patterns)

    S = createInitSet(input_new())

    for min_support in [2,4,8,16,32,64]:
        print "\nmin_support = %d: "%min_support
        patterns = prefixSpan(SquencePattern([], sys.maxint), S, min_support)
        print_patterns(patterns)
# Out:
# min_support = 2:
# pattern:[['11521012.0']], support:2
# pattern:[['10113005.0']], support:2
# pattern:[['10113005.0', '27000582.0']], support:2
# pattern:[['27400118.0']], support:2
# pattern:[['14091007.0']], support:2
# pattern:[['14091009.0']], support:2
# pattern:[['14081006.0']], support:2
# pattern:[['14839016.0']], support:2
# pattern:[['27002559.0']], support:2
# pattern:[['22040157.0']], support:2
# pattern:[['14132170.0']], support:2
# pattern:[['14200040.0']], support:2
# pattern:[['14200040.0', '30380002.0']], support:2
# pattern:[['10501076.0']], support:2
# pattern:[['15202020.0']], support:2
# pattern:[['15209007.0']], support:2
# pattern:[['14822002.0']], support:2
# pattern:[['14847018.0']], support:2
# pattern:[['14831007.0']], support:2
# pattern:[['14831007.0', '25120036.0']], support:2
# pattern:[['14831007.0', '14900007.0']], support:2
# pattern:[['14831007.0', '14900007.0', '25120036.0']], support:2
# pattern:[['20110014.0']], support:2
# pattern:[['14015066.0']], support:2
# pattern:[['14092042.0']], support:2
# pattern:[['14721071.0']], support:2
# pattern:[['14721017.0']], support:2
# pattern:[['22190002.0']], support:2
# pattern:[['15000048.0']], support:2
# pattern:[['10131021.0']], support:2
# pattern:[['10131021.0', '15130027.0']], support:2
# pattern:[['14831008.0']], support:2
# pattern:[['14530015.0']], support:2
# pattern:[['14231008.0']], support:2
# pattern:[['15110046.0']], support:2
# pattern:[['22020010.0']], support:2
# pattern:[['14710025.0']], support:2
# pattern:[['14710025.0', '24101003.0']], support:2
# pattern:[['11502024.0']], support:2
# pattern:[['15115010.0']], support:2
# pattern:[['15115010.0', '30380003.0']], support:2
# pattern:[['11500127.0']], support:2
# pattern:[['11500127.0', '11501093.0']], support:2
# pattern:[['14802020.0']], support:2
# pattern:[['14802020.0', '21801125.0']], support:2
# pattern:[['24403016.0']], support:2
# pattern:[['22111024.0']], support:2
# pattern:[['15000006.0']], support:2
# pattern:[['10422012.0']], support:2
# pattern:[['34304010.0']], support:2
# pattern:[['23113024.0']], support:2
# pattern:[['14121041.0']], support:2
# pattern:[['14834007.0']], support:2
# pattern:[['14834007.0', '14834008.0']], support:2
# pattern:[['15113002.0']], support:2
# pattern:[['10150006.0']], support:2
# pattern:[['10150006.0', '22036000.0']], support:2
# pattern:[['10119139.0']], support:2
# pattern:[['14082024.0']], support:2
# pattern:[['14082024.0', '30380003.0']], support:2
# pattern:[['14092067.0']], support:2
# pattern:[['23104035.0']], support:2
# pattern:[['10119078.0']], support:2
# pattern:[['10119078.0', '10131020.0']], support:2
# pattern:[['14916008.0']], support:2
# pattern:[['10140005.0']], support:2
# pattern:[['23113005.0']], support:2
# pattern:[['10141052.0']], support:2
# pattern:[['22130018.0']], support:2
# pattern:[['22005006.0']], support:2
# pattern:[['10008008.0']], support:2
# pattern:[['22100025.0']], support:2
# pattern:[['15202013.0']], support:2
# pattern:[['15202013.0', '15232001.0']], support:2
# pattern:[['14721042.0']], support:2
# pattern:[['15202011.0']], support:2
# pattern:[['14860014.0']], support:2
# pattern:[['14015065.0']], support:2
# pattern:[['14015065.0', '27300274.0']], support:2
# pattern:[['14015065.0', '22111031.0']], support:2
# pattern:[['14015065.0', '22111031.0', '25100108.0']], support:2
# pattern:[['14015065.0', '22111031.0', '25100108.0', '27300274.0']], support:2
# pattern:[['14015065.0', '22111031.0', '27300274.0']], support:2
# pattern:[['14015065.0', '25100108.0']], support:2
# pattern:[['14015065.0', '25100108.0', '27300274.0']], support:2
# pattern:[['14043022.0']], support:2
# pattern:[['11500027.0']], support:2
# pattern:[['15502037.0']], support:2
# pattern:[['14721083.0']], support:2
# pattern:[['25121074.0']], support:2
# pattern:[['14812008.0']], support:2
# pattern:[['15001003.0']], support:2
# pattern:[['14121012.0']], support:2
# pattern:[['15004087.0']], support:2
# pattern:[['14905010.0']], support:2
# pattern:[['14905010.0', '25111048.0']], support:2
# pattern:[['14770025.0']], support:2
# pattern:[['21801107.0']], support:2
# pattern:[['14830021.0']], support:2
# pattern:[['14220002.0']], support:2
# pattern:[['14220002.0', '14222018.0']], support:2
# pattern:[['14220002.0', '14222018.0', '30380002.0']], support:2
# pattern:[['14220002.0', '30380002.0']], support:2
# pattern:[['10132002.0']], support:2
# pattern:[['15202028.0']], support:2
# pattern:[['15202028.0', '23110009.0']], support:2
# pattern:[['14243002.0']], support:2
# pattern:[['14078003.0']], support:2
# pattern:[['14200051.0']], support:2
# pattern:[['14090020.0']], support:2
# pattern:[['14651005.0']], support:2
# pattern:[['14651005.0', '25101002.0']], support:2
# pattern:[['14651005.0', '15202079.0']], support:2
# pattern:[['14651005.0', '15202079.0', '25101002.0']], support:2
# pattern:[['14651005.0', '15200007.0']], support:2
# pattern:[['14651005.0', '15200007.0', '25101002.0']], support:2
# pattern:[['14651005.0', '15200007.0', '15202079.0']], support:2
# pattern:[['14651005.0', '15200007.0', '15202079.0', '25101002.0']], support:2
# pattern:[['11533029.0']], support:2
# pattern:[['15234002.0']], support:2
# pattern:[['15234002.0', '23132068.0']], support:2
# pattern:[['15234002.0', '22600002.0']], support:2
# pattern:[['15234002.0', '22600002.0', '23132068.0']], support:2
# pattern:[['15402027.0']], support:2
# pattern:[['14260008.0']], support:2
# pattern:[['14260008.0', '15114015.0']], support:2
# pattern:[['11303081.0']], support:2
# pattern:[['11303087.0']], support:2
# pattern:[['14900012.0']], support:2
# pattern:[['27002572.0']], support:2
# pattern:[['11531047.0']], support:2
# pattern:[['11501099.0']], support:2
# pattern:[['22111008.0']], support:2
# pattern:[['14811004.0']], support:2
# pattern:[['10200043.0']], support:2
# pattern:[['10300030.0']], support:2
# pattern:[['22002005.0']], support:2
# pattern:[['15110002.0']], support:2
# pattern:[['25121013.0']], support:2
# pattern:[['14092015.0']], support:2
# pattern:[['10200041.0']], support:2
# pattern:[['11301091.0']], support:2
# pattern:[['10502045.0']], support:2
# pattern:[['11521005.0']], support:2
# pattern:[['11521005.0', '24101003.0']], support:2
# pattern:[['14054002.0']], support:2
# pattern:[['11221037.0']], support:2
# pattern:[['10502000.0']], support:2
# pattern:[['27000611.0']], support:2
# pattern:[['22603000.0']], support:2
# pattern:[['10119074.0']], support:2
# pattern:[['10119074.0', '10153003.0']], support:2
# pattern:[['10119074.0', '10153003.0', '10422012.0']], support:2
# pattern:[['10119074.0', '10422012.0']], support:2
# pattern:[['10501053.0']], support:2
# pattern:[['14076021.0']], support:2
# pattern:[['14072004.0']], support:2
# pattern:[['14300099.0']], support:2
# pattern:[['14300099.0', '27400145.0']], support:2
# pattern:[['15502049.0']], support:2
# pattern:[['14120013.0']], support:2
# pattern:[['14802057.0']], support:2
# pattern:[['14721023.0']], support:2
# pattern:[['15110033.0']], support:2
# pattern:[['15004010.0']], support:2
# pattern:[['15004010.0', '15200007.0']], support:2
# pattern:[['14721035.0']], support:2
# pattern:[['14721035.0', '15114000.0']], support:2
# pattern:[['15110007.0']], support:2
# pattern:[['15110007.0', '23110144.0']], support:2
# pattern:[['15110007.0', '15110036.0']], support:2
# pattern:[['15110007.0', '15110036.0', '23110144.0']], support:2
# pattern:[['30320001.0']], support:2
# pattern:[['10150033.0']], support:2
# pattern:[['10150033.0', '30380002.0']], support:2
# pattern:[['10150033.0', '27200170.0']], support:2
# pattern:[['10150033.0', '27200170.0', '30380002.0']], support:2
# pattern:[['10150033.0', '25111048.0']], support:2
# pattern:[['10150033.0', '25111048.0', '30380002.0']], support:2
# pattern:[['10150033.0', '25111048.0', '27200170.0']], support:2
# pattern:[['10150033.0', '25111048.0', '27200170.0', '30380002.0']], support:2
# pattern:[['15110003.0']], support:2
# pattern:[['27300279.0']], support:2
# pattern:[['10114004.0']], support:2
# pattern:[['10150019.0']], support:2
# pattern:[['10150019.0', '30380003.0']], support:2
# pattern:[['15110005.0']], support:2
# pattern:[['15115015.0']], support:2
# pattern:[['22021009.0']], support:2
# pattern:[['10141012.0']], support:2
# pattern:[['15139013.0']], support:2
# pattern:[['22111029.0']], support:2
# pattern:[['22103072.0']], support:2
# pattern:[['10300043.0']], support:2
# pattern:[['10300043.0', '22008019.0']], support:2
# pattern:[['10300043.0', '22008019.0', '23113027.0']], support:2
# pattern:[['10300043.0', '15113004.0']], support:2
# pattern:[['10300043.0', '15113004.0', '22008019.0']], support:2
# pattern:[['10300043.0', '15113004.0', '22008019.0', '23113027.0']], support:2
# pattern:[['10300043.0', '15113004.0', '23113027.0']], support:2
# pattern:[['10300043.0', '23113027.0']], support:2
# pattern:[['15435002.0']], support:2
# pattern:[['15435002.0', '22111012.0']], support:2
# pattern:[['14060006.0']], support:2
# pattern:[['22501003.0']], support:2
# pattern:[['15120015.0']], support:2
# pattern:[['14092062.0']], support:2
# pattern:[['15231006.0']], support:2
# pattern:[['11300133.0']], support:2
# pattern:[['14050012.0']], support:2
# pattern:[['10140006.0']], support:2
# pattern:[['22511000.0']], support:2
# pattern:[['14636010.0']], support:2
# pattern:[['24010809.0']], support:2
# pattern:[['22001006.0']], support:2
# pattern:[['10202000.0']], support:2
# pattern:[['14230000.0']], support:2
# pattern:[['22671068.0']], support:2
# pattern:[['10501026.0']], support:2
# pattern:[['27000020.0']], support:2
# pattern:[['27000020.0', '27300274.0']], support:2
# pattern:[['27000020.0', '27300274.0', '27410000.0']], support:2
# pattern:[['27000020.0', '27410000.0']], support:2
# pattern:[['22030008.0']], support:2
# pattern:[['11044019.0']], support:2
# pattern:[['27000575.0']], support:2
# pattern:[['10150050.0']], support:2
# pattern:[['15115044.0']], support:2
# pattern:[['15202018.0']], support:2
# pattern:[['15502030.0']], support:2
# pattern:[['14092073.0']], support:2
# pattern:[['14408000.0']], support:2
# pattern:[['22007008.0']], support:2
# pattern:[['14722071.0']], support:2
# pattern:[['27410004.0']], support:2
# pattern:[['11501093.0']], support:2
# pattern:[['15242011.0']], support:2
# pattern:[['15242011.0', '22102014.0']], support:2
# pattern:[['14903003.0']], support:2
# pattern:[['14833011.0']], support:2
# pattern:[['14403013.0']], support:2
# pattern:[['22610002.0']], support:2
# pattern:[['23110186.0']], support:2
# pattern:[['10119082.0']], support:2
# pattern:[['11521025.0']], support:2
# pattern:[['11521025.0', '30380002.0']], support:2
# pattern:[['10401024.0']], support:2
# pattern:[['14654000.0']], support:2
# pattern:[['11501070.0']], support:2
# pattern:[['14084003.0']], support:2
# pattern:[['14205014.0']], support:2
# pattern:[['14073020.0']], support:2
# pattern:[['15114014.0']], support:2
# pattern:[['15209032.0']], support:2
# pattern:[['11110152.0']], support:2
# pattern:[['15202037.0']], support:2
# pattern:[['11521029.0']], support:2
# pattern:[['15116003.0']], support:2
# pattern:[['10500024.0']], support:2
# pattern:[['11533011.0']], support:2
# pattern:[['14844021.0']], support:2
# pattern:[['14092043.0']], support:2
# pattern:[['15119009.0']], support:2
# pattern:[['14900013.0']], support:2
# pattern:[['22621002.0']], support:2
# pattern:[['15115025.0']], support:2
# pattern:[['15115025.0', '22102014.0']], support:2
# pattern:[['15115025.0', '15230002.0']], support:2
# pattern:[['15115025.0', '15230002.0', '22102014.0']], support:2
# pattern:[['15115025.0', '15130027.0']], support:2
# pattern:[['15115025.0', '15130027.0', '22102014.0']], support:2
# pattern:[['15115025.0', '15130027.0', '15230002.0']], support:2
# pattern:[['15115025.0', '15130027.0', '15230002.0', '22102014.0']], support:2
# pattern:[['24000372.0']], support:2
# pattern:[['27002582.0']], support:2
# pattern:[['14900017.0']], support:2
# pattern:[['14721021.0']], support:2
# pattern:[['14010011.0']], support:2
# pattern:[['14010011.0', '14013010.0']], support:2
# pattern:[['14900015.0']], support:2
# pattern:[['22171000.0']], support:2
# pattern:[['15115013.0']], support:2
# pattern:[['14900005.0']], support:2
# pattern:[['14900005.0', '14900007.0']], support:2
# pattern:[['15115037.0']], support:2
# pattern:[['15110021.0']], support:2
# pattern:[['15110021.0', '22600000.0']], support:2
# pattern:[['15110021.0', '22600000.0', '27400289.0']], support:2
# pattern:[['15110021.0', '15114013.0']], support:2
# pattern:[['15110021.0', '15114013.0', '22600000.0']], support:2
# pattern:[['15110021.0', '15114013.0', '22600000.0', '27400289.0']], support:2
# pattern:[['15110021.0', '15114013.0', '27400289.0']], support:2
# pattern:[['15110021.0', '27400289.0']], support:2
# pattern:[['15119007.0']], support:2
# pattern:[['30321008.0']], support:2
# pattern:[['14844029.0']], support:2
# pattern:[['14902001.0']], support:2
# pattern:[['10141030.0']], support:2
# pattern:[['10141030.0', '27200924.0']], support:2
# pattern:[['10141030.0', '27200924.0', '27410003.0']], support:2
# pattern:[['10141030.0', '27200924.0', '27410003.0', '30380003.0']], support:2
# pattern:[['10141030.0', '27200924.0', '30380003.0']], support:2
# pattern:[['10141030.0', '30380003.0']], support:2
# pattern:[['10141030.0', '27410003.0']], support:2
# pattern:[['10141030.0', '27410003.0', '30380003.0']], support:2
# pattern:[['10300035.0']], support:2
# pattern:[['15130012.0']], support:2
# pattern:[['14900009.0']], support:2
# pattern:[['15605048.0']], support:2
# pattern:[['14750042.0']], support:2
# pattern:[['27002575.0']], support:2
# pattern:[['32736023.0']], support:2
# pattern:[['15114036.0']], support:2
# pattern:[['22001038.0']], support:2
# pattern:[['22103013.0']], support:2
# pattern:[['22111015.0']], support:2
# pattern:[['27002561.0']], support:2
# pattern:[['11501065.0']], support:2
# pattern:[['11501065.0', '30380003.0']], support:2
# pattern:[['15433002.0']], support:2
# pattern:[['14082011.0']], support:2
# pattern:[['11230157.0']], support:2
# pattern:[['24101076.0']], support:2
# pattern:[['10140008.0']], support:2
# pattern:[['22110004.0']], support:2
# pattern:[['21012004.0']], support:2
# pattern:[['22103007.0']], support:2
# pattern:[['22103007.0', '22103011.0']], support:2
# pattern:[['22103007.0', '22103011.0', '27410002.0']], support:2
# pattern:[['22103007.0', '27410002.0']], support:2
# pattern:[['14080016.0']], support:2
# pattern:[['10131007.0']], support:2
# pattern:[['34225051.0']], support:2
# pattern:[['14700032.0']], support:2
# pattern:[['15503041.0']], support:2
# pattern:[['11220042.0']], support:2
# pattern:[['14775014.0']], support:2
# pattern:[['10150032.0']], support:2
# pattern:[['10150032.0', '30380002.0']], support:2
# pattern:[['10150032.0', '27410003.0']], support:2
# pattern:[['10150032.0', '27410003.0', '30380002.0']], support:2
# pattern:[['15605064.0']], support:2
# pattern:[['10150018.0']], support:2
# pattern:[['21812019.0']], support:2
# pattern:[['10150026.0']], support:2
# pattern:[['10150026.0', '23110009.0']], support:2
# pattern:[['15111005.0']], support:2
# pattern:[['32416009.0']], support:2
# pattern:[['22702005.0']], support:2
# pattern:[['10150022.0']], support:2
# pattern:[['27300278.0']], support:2
# pattern:[['24010556.0']], support:2
# pattern:[['14054014.0']], support:2
# pattern:[['14362001.0']], support:2
# pattern:[['15201001.0']], support:2
# pattern:[['14409044.0']], support:2
# pattern:[['14841008.0']], support:2
# pattern:[['14841008.0', '14860017.0']], support:2
# pattern:[['22713008.0']], support:2
# pattern:[['14050013.0']], support:2
# pattern:[['14332005.0']], support:2
# pattern:[['14332005.0', '15114013.0']], support:2
# pattern:[['22851000.0']], support:2
# pattern:[['15605006.0']], support:2
# pattern:[['14871000.0']], support:2
# pattern:[['15116001.0']], support:2
# pattern:[['15202019.0']], support:2
# pattern:[['15202019.0', '30380003.0']], support:2
# pattern:[['40000667.0']], support:2
# pattern:[['10002019.0']], support:2
# pattern:[['11533015.0']], support:2
# pattern:[['14063000.0']], support:2
# pattern:[['10501085.0']], support:2
# pattern:[['23110172.0']], support:2
# pattern:[['23110172.0', '30380003.0']], support:2
# pattern:[['15149011.0']], support:2
# pattern:[['24010000.0']], support:2
# pattern:[['15149005.0']], support:2
# pattern:[['15149005.0', '30380003.0']], support:2
# pattern:[['14580017.0']], support:2
# pattern:[['11011029.0']], support:2
# pattern:[['22830002.0']], support:2
# pattern:[['11531010.0']], support:2
# pattern:[['10130011.0']], support:2
# pattern:[['24102002.0']], support:2
# pattern:[['14836014.0']], support:2
# pattern:[['11521008.0']], support:2
# pattern:[['10153003.0']], support:2
# pattern:[['10153003.0', '10422012.0']], support:2
# pattern:[['14903006.0']], support:2
# pattern:[['14300007.0']], support:2
# pattern:[['11110046.0']], support:2
# pattern:[['14900021.0']], support:3
# pattern:[['10131001.0']], support:3
# pattern:[['14843019.0']], support:3
# pattern:[['24111015.0']], support:3
# pattern:[['23113003.0']], support:3
# pattern:[['14831015.0']], support:3
# pattern:[['14831015.0', '22102014.0']], support:2
# pattern:[['15120006.0']], support:3
# pattern:[['14261003.0']], support:3
# pattern:[['14261003.0', '14513033.0']], support:2
# pattern:[['14721022.0']], support:3
# pattern:[['22172000.0']], support:3
# pattern:[['22172000.0', '27300276.0']], support:2
# pattern:[['24403046.0']], support:3
# pattern:[['27002560.0']], support:3
# pattern:[['27002194.0']], support:3
# pattern:[['27002194.0', '27300273.0']], support:2
# pattern:[['22111026.0']], support:3
# pattern:[['14861002.0']], support:3
# pattern:[['10422010.0']], support:3
# pattern:[['10422010.0', '22003002.0']], support:2
# pattern:[['10422010.0', '15004053.0']], support:2
# pattern:[['10422010.0', '15004053.0', '30380002.0']], support:2
# pattern:[['10422010.0', '30380002.0']], support:2
# pattern:[['14082026.0']], support:3
# pattern:[['14082026.0', '24101000.0']], support:2
# pattern:[['10422006.0']], support:3
# pattern:[['10422006.0', '22100010.0']], support:2
# pattern:[['15605059.0']], support:3
# pattern:[['14222033.0']], support:3
# pattern:[['14222033.0', '14222034.0']], support:2
# pattern:[['10150049.0']], support:3
# pattern:[['10150049.0', '15240016.0']], support:2
# pattern:[['10150049.0', '15240016.0', '27000582.0']], support:2
# pattern:[['10150049.0', '27000582.0']], support:3
# pattern:[['15115043.0']], support:3
# pattern:[['15202001.0']], support:3
# pattern:[['15430000.0']], support:3
# pattern:[['15430000.0', '25100108.0']], support:2
# pattern:[['15430000.0', '25100108.0', '27300276.0']], support:2
# pattern:[['15430000.0', '25100108.0', '27300274.0']], support:2
# pattern:[['15430000.0', '25100108.0', '27300274.0', '27300276.0']], support:2
# pattern:[['15430000.0', '27300276.0']], support:2
# pattern:[['15430000.0', '27300274.0']], support:3
# pattern:[['15430000.0', '27300274.0', '27300276.0']], support:2
# pattern:[['15110027.0']], support:3
# pattern:[['10130013.0']], support:3
# pattern:[['22000005.0']], support:3
# pattern:[['22000005.0', '22111004.0']], support:2
# pattern:[['22000005.0', '22500022.0']], support:2
# pattern:[['22004008.0']], support:3
# pattern:[['14050014.0']], support:3
# pattern:[['15605013.0']], support:3
# pattern:[['23110185.0']], support:3
# pattern:[['23110185.0', '23120001.0']], support:2
# pattern:[['23142046.0']], support:3
# pattern:[['23142046.0', '30380003.0']], support:2
# pattern:[['14092068.0']], support:3
# pattern:[['14092068.0', '30380003.0']], support:2
# pattern:[['14091073.0']], support:3
# pattern:[['14091073.0', '30380002.0']], support:2
# pattern:[['14130054.0']], support:3
# pattern:[['14130054.0', '27400855.0']], support:2
# pattern:[['15004053.0']], support:3
# pattern:[['15004053.0', '30380002.0']], support:2
# pattern:[['22002259.0']], support:3
# pattern:[['10002022.0']], support:3
# pattern:[['22610103.0']], support:3
# pattern:[['11500080.0']], support:3
# pattern:[['11500080.0', '23132061.0']], support:2
# pattern:[['15004041.0']], support:3
# pattern:[['15004041.0', '27410001.0']], support:2
# pattern:[['15114037.0']], support:3
# pattern:[['15114037.0', '15120000.0']], support:2
# pattern:[['15110038.0']], support:3
# pattern:[['14010012.0']], support:3
# pattern:[['24000373.0']], support:3
# pattern:[['14076012.0']], support:3
# pattern:[['10141019.0']], support:3
# pattern:[['14121037.0']], support:3
# pattern:[['23130012.0']], support:3
# pattern:[['15115028.0']], support:3
# pattern:[['24000393.0']], support:3
# pattern:[['25100113.0']], support:3
# pattern:[['14000002.0']], support:3
# pattern:[['14000002.0', '25101044.0']], support:2
# pattern:[['14000002.0', '25101044.0', '27300274.0']], support:2
# pattern:[['14000002.0', '27300274.0']], support:3
# pattern:[['11501048.0']], support:3
# pattern:[['11501048.0', '30380003.0']], support:2
# pattern:[['22103012.0']], support:3
# pattern:[['27002554.0']], support:3
# pattern:[['11141002.0']], support:3
# pattern:[['10131020.0']], support:3
# pattern:[['14091046.0']], support:3
# pattern:[['14091046.0', '14091047.0']], support:2
# pattern:[['10150021.0']], support:3
# pattern:[['15012007.0']], support:3
# pattern:[['15012007.0', '30380002.0']], support:2
# pattern:[['22802001.0']], support:3
# pattern:[['14834008.0']], support:3
# pattern:[['22040009.0']], support:3
# pattern:[['14082023.0']], support:3
# pattern:[['14082023.0', '27400855.0']], support:2
# pattern:[['14130017.0']], support:3
# pattern:[['15242009.0']], support:3
# pattern:[['14407009.0']], support:3
# pattern:[['14407009.0', '25120016.0']], support:2
# pattern:[['14407009.0', '24101000.0']], support:2
# pattern:[['14407009.0', '24101000.0', '25120016.0']], support:2
# pattern:[['10002000.0']], support:3
# pattern:[['14222018.0']], support:3
# pattern:[['14222018.0', '30380002.0']], support:2
# pattern:[['15110000.0']], support:3
# pattern:[['27400289.0']], support:3
# pattern:[['27400289.0', '30380003.0']], support:2
# pattern:[['15502036.0']], support:3
# pattern:[['15502036.0', '15503022.0']], support:2
# pattern:[['22102004.0']], support:3
# pattern:[['10141039.0']], support:3
# pattern:[['23110188.0']], support:3
# pattern:[['23110188.0', '23120001.0']], support:2
# pattern:[['14830014.0']], support:3
# pattern:[['22172012.0']], support:3
# pattern:[['24102005.0']], support:3
# pattern:[['27000035.0']], support:3
# pattern:[['27000035.0', '27410000.0']], support:2
# pattern:[['15242005.0']], support:3
# pattern:[['15242005.0', '25101044.0']], support:3
# pattern:[['21801072.0']], support:3
# pattern:[['15240016.0']], support:3
# pattern:[['15240016.0', '27000582.0']], support:3
# pattern:[['10132017.0']], support:3
# pattern:[['10132017.0', '30380002.0']], support:2
# pattern:[['10132017.0', '10133001.0']], support:2
# pattern:[['10132017.0', '10133001.0', '30380002.0']], support:2
# pattern:[['15230004.0']], support:3
# pattern:[['15230004.0', '30380003.0']], support:2
# pattern:[['14710009.0']], support:3
# pattern:[['15200009.0']], support:3
# pattern:[['15200009.0', '25111048.0']], support:2
# pattern:[['22102009.0']], support:3
# pattern:[['32143002.0']], support:3
# pattern:[['10119057.0']], support:3
# pattern:[['10119057.0', '30380003.0']], support:2
# pattern:[['10119057.0', '34225051.0']], support:2
# pattern:[['10119057.0', '27400145.0']], support:3
# pattern:[['10119057.0', '27400145.0', '34225051.0']], support:2
# pattern:[['10119057.0', '27400145.0', '30380003.0']], support:2
# pattern:[['10119057.0', '10141044.0']], support:3
# pattern:[['10119057.0', '10141044.0', '30380003.0']], support:2
# pattern:[['10119057.0', '10141044.0', '34225051.0']], support:2
# pattern:[['10119057.0', '10141044.0', '27400145.0']], support:3
# pattern:[['10119057.0', '10141044.0', '27400145.0', '34225051.0']], support:2
# pattern:[['10119057.0', '10141044.0', '27400145.0', '30380003.0']], support:2
# pattern:[['14000011.0']], support:3
# pattern:[['14750067.0']], support:3
# pattern:[['22001000.0']], support:3
# pattern:[['30710042.0']], support:3
# pattern:[['14802056.0']], support:3
# pattern:[['14802056.0', '23110009.0']], support:2
# pattern:[['22003002.0']], support:3
# pattern:[['14105020.0']], support:3
# pattern:[['15110008.0']], support:3
# pattern:[['27002186.0']], support:3
# pattern:[['15212006.0']], support:3
# pattern:[['24401008.0']], support:3
# pattern:[['24401008.0', '27002167.0']], support:2
# pattern:[['22130000.0']], support:3
# pattern:[['22630010.0']], support:3
# pattern:[['14905003.0']], support:3
# pattern:[['14905007.0']], support:3
# pattern:[['14905007.0', '27000582.0']], support:2
# pattern:[['34133016.0']], support:3
# pattern:[['32917001.0']], support:3
# pattern:[['10151000.0']], support:3
# pattern:[['10151000.0', '30380003.0']], support:3
# pattern:[['14092059.0']], support:3
# pattern:[['27000033.0']], support:3
# pattern:[['14130025.0']], support:3
# pattern:[['10141038.0']], support:3
# pattern:[['10141038.0', '30380003.0']], support:2
# pattern:[['22671080.0']], support:3
# pattern:[['22180003.0']], support:3
# pattern:[['27002173.0']], support:3
# pattern:[['15110073.0']], support:3
# pattern:[['23113019.0']], support:4
# pattern:[['23113019.0', '30380003.0']], support:2
# pattern:[['22103003.0']], support:4
# pattern:[['24011018.0']], support:4
# pattern:[['24011018.0', '24101000.0']], support:2
# pattern:[['23112032.0']], support:4
# pattern:[['40000700.0']], support:4
# pattern:[['14750041.0']], support:4
# pattern:[['14750041.0', '22111004.0']], support:2
# pattern:[['14750041.0', '22102014.0']], support:3
# pattern:[['14750041.0', '22102014.0', '22111004.0']], support:2
# pattern:[['22103008.0']], support:4
# pattern:[['22103008.0', '27000576.0']], support:2
# pattern:[['15113004.0']], support:4
# pattern:[['15113004.0', '22008019.0']], support:2
# pattern:[['15113004.0', '22008019.0', '23113027.0']], support:2
# pattern:[['15113004.0', '23113027.0']], support:2
# pattern:[['22005000.0']], support:4
# pattern:[['15503022.0']], support:4
# pattern:[['15503022.0', '30380002.0']], support:2
# pattern:[['22604000.0']], support:4
# pattern:[['22630009.0']], support:4
# pattern:[['22630009.0', '27000581.0']], support:2
# pattern:[['14020005.0']], support:4
# pattern:[['27002440.0']], support:4
# pattern:[['22120005.0']], support:4
# pattern:[['22120005.0', '22170001.0']], support:2
# pattern:[['14802055.0']], support:4
# pattern:[['14802055.0', '14916008.0']], support:2
# pattern:[['27410007.0']], support:4
# pattern:[['11110050.0']], support:4
# pattern:[['14091028.0']], support:4
# pattern:[['14091028.0', '30380003.0']], support:2
# pattern:[['30323001.0']], support:4
# pattern:[['10130010.0']], support:4
# pattern:[['10130010.0', '30380003.0']], support:2
# pattern:[['10130010.0', '10133001.0']], support:3
# pattern:[['10130010.0', '10133001.0', '30380003.0']], support:2
# pattern:[['22172008.0']], support:4
# pattern:[['10150004.0']], support:4
# pattern:[['10150004.0', '30380003.0']], support:2
# pattern:[['10130006.0']], support:4
# pattern:[['15115000.0']], support:4
# pattern:[['15115000.0', '15115001.0']], support:2
# pattern:[['15115000.0', '23142046.0']], support:2
# pattern:[['15115000.0', '23142046.0', '30380003.0']], support:2
# pattern:[['15115000.0', '30380003.0']], support:3
# pattern:[['15022003.0']], support:4
# pattern:[['22840002.0']], support:4
# pattern:[['22840002.0', '30380002.0']], support:2
# pattern:[['22111006.0']], support:4
# pattern:[['24011017.0']], support:4
# pattern:[['24011017.0', '25101044.0']], support:2
# pattern:[['14092023.0']], support:4
# pattern:[['14092023.0', '30380002.0']], support:2
# pattern:[['15113000.0']], support:4
# pattern:[['15113000.0', '30380002.0']], support:2
# pattern:[['15110080.0']], support:4
# pattern:[['15110080.0', '30380003.0']], support:2
# pattern:[['15114032.0']], support:4
# pattern:[['15110035.0']], support:4
# pattern:[['15110035.0', '15130027.0']], support:2
# pattern:[['10502006.0']], support:4
# pattern:[['27002573.0']], support:4
# pattern:[['10136007.0']], support:4
# pattern:[['11300123.0']], support:4
# pattern:[['15231008.0']], support:4
# pattern:[['15231008.0', '23110009.0']], support:2
# pattern:[['11110052.0']], support:4
# pattern:[['24010825.0']], support:4
# pattern:[['24010825.0', '27410000.0']], support:2
# pattern:[['24010825.0', '25120036.0']], support:2
# pattern:[['14860021.0']], support:4
# pattern:[['10141021.0']], support:4
# pattern:[['10137009.0']], support:4
# pattern:[['10137009.0', '10422010.0']], support:2
# pattern:[['10137009.0', '10422010.0', '15004053.0']], support:2
# pattern:[['10137009.0', '10422010.0', '15004053.0', '30380002.0']], support:2
# pattern:[['10137009.0', '10422010.0', '30380002.0']], support:2
# pattern:[['10137009.0', '15004053.0']], support:2
# pattern:[['10137009.0', '15004053.0', '30380002.0']], support:2
# pattern:[['10137009.0', '30380002.0']], support:2
# pattern:[['24010016.0']], support:4
# pattern:[['15110076.0']], support:4
# pattern:[['15110076.0', '30380003.0']], support:2
# pattern:[['24101005.0']], support:4
# pattern:[['10152013.0']], support:4
# pattern:[['10152013.0', '30380002.0']], support:2
# pattern:[['10152013.0', '30380003.0']], support:2
# pattern:[['10152013.0', '27300273.0']], support:2
# pattern:[['10152013.0', '27300273.0', '30380002.0']], support:2
# pattern:[['10152013.0', '27000581.0']], support:2
# pattern:[['10152013.0', '27000581.0', '27300273.0']], support:2
# pattern:[['10152013.0', '27000581.0', '27300273.0', '30380002.0']], support:2
# pattern:[['10152013.0', '27000581.0', '30380002.0']], support:2
# pattern:[['15115001.0']], support:4
# pattern:[['14900007.0']], support:4
# pattern:[['14900007.0', '23110009.0']], support:2
# pattern:[['14900007.0', '23110009.0', '25120036.0']], support:2
# pattern:[['14900007.0', '25120036.0']], support:3
# pattern:[['22102001.0']], support:4
# pattern:[['22180002.0']], support:4
# pattern:[['30321004.0']], support:4
# pattern:[['14092022.0']], support:4
# pattern:[['10119138.0']], support:4
# pattern:[['14052005.0']], support:4
# pattern:[['14052005.0', '30380003.0']], support:3
# pattern:[['27002436.0']], support:4
# pattern:[['27002436.0', '30380002.0']], support:2
# pattern:[['27002436.0', '27300282.0']], support:2
# pattern:[['15202044.0']], support:4
# pattern:[['25405948.0']], support:4
# pattern:[['22008019.0']], support:4
# pattern:[['22008019.0', '23134003.0']], support:2
# pattern:[['22008019.0', '23113027.0']], support:2
# pattern:[['11301004.0']], support:4
# pattern:[['11110004.0']], support:4
# pattern:[['15200001.0']], support:4
# pattern:[['15200001.0', '30380003.0']], support:2
# pattern:[['10000015.0']], support:4
# pattern:[['10000015.0', '27410003.0']], support:2
# pattern:[['15120000.0']], support:5
# pattern:[['15120000.0', '15130006.0']], support:2
# pattern:[['15114003.0']], support:5
# pattern:[['15114003.0', '22500022.0']], support:2
# pattern:[['15110014.0']], support:5
# pattern:[['15114033.0']], support:5
# pattern:[['22103004.0']], support:5
# pattern:[['22103004.0', '25101044.0']], support:2
# pattern:[['22103004.0', '25101044.0', '27410000.0']], support:2
# pattern:[['22103004.0', '27410000.0']], support:2
# pattern:[['15114004.0']], support:5
# pattern:[['15114004.0', '23110009.0']], support:2
# pattern:[['15114004.0', '30380003.0']], support:3
# pattern:[['15114004.0', '15114005.0']], support:3
# pattern:[['15114004.0', '15114005.0', '30380003.0']], support:2
# pattern:[['27000007.0']], support:5
# pattern:[['27000007.0', '27410002.0']], support:3
# pattern:[['10000011.0']], support:5
# pattern:[['10000011.0', '27410003.0']], support:2
# pattern:[['10000011.0', '27410003.0', '30380002.0']], support:2
# pattern:[['10000011.0', '30380002.0']], support:2
# pattern:[['10000011.0', '27200924.0']], support:2
# pattern:[['10000011.0', '10150032.0']], support:2
# pattern:[['10000011.0', '10150032.0', '30380002.0']], support:2
# pattern:[['10000011.0', '10150032.0', '27410003.0']], support:2
# pattern:[['10000011.0', '10150032.0', '27410003.0', '30380002.0']], support:2
# pattern:[['10000011.0', '24101002.0']], support:2
# pattern:[['10141026.0']], support:5
# pattern:[['10141026.0', '30380003.0']], support:2
# pattern:[['23110193.0']], support:5
# pattern:[['23110193.0', '27300273.0']], support:2
# pattern:[['32917000.0']], support:5
# pattern:[['24101002.0']], support:5
# pattern:[['15202002.0']], support:5
# pattern:[['10000016.0']], support:5
# pattern:[['15110036.0']], support:5
# pattern:[['15110036.0', '22103010.0']], support:2
# pattern:[['15110036.0', '23110144.0']], support:2
# pattern:[['27002176.0']], support:5
# pattern:[['27002174.0']], support:5
# pattern:[['27002174.0', '27300274.0']], support:2
# pattern:[['27002174.0', '27410000.0']], support:2
# pattern:[['14750064.0']], support:5
# pattern:[['14750064.0', '15110008.0']], support:2
# pattern:[['10110017.0']], support:5
# pattern:[['15120005.0']], support:5
# pattern:[['15242044.0']], support:5
# pattern:[['15242044.0', '27300274.0']], support:2
# pattern:[['15242044.0', '25100108.0']], support:2
# pattern:[['15242044.0', '25100108.0', '27300274.0']], support:2
# pattern:[['15242044.0', '23132068.0']], support:2
# pattern:[['15242044.0', '23132068.0', '27300274.0']], support:2
# pattern:[['15242044.0', '23132068.0', '25100108.0']], support:2
# pattern:[['15242044.0', '23132068.0', '25100108.0', '27300274.0']], support:2
# pattern:[['22130007.0']], support:5
# pattern:[['22130007.0', '30380002.0']], support:2
# pattern:[['22130007.0', '27300274.0']], support:2
# pattern:[['22130007.0', '27410000.0']], support:2
# pattern:[['15231004.0']], support:5
# pattern:[['15231004.0', '27400855.0']], support:2
# pattern:[['15231004.0', '30380003.0']], support:3
# pattern:[['22000029.0']], support:5
# pattern:[['23110155.0']], support:5
# pattern:[['14750001.0']], support:5
# pattern:[['14750001.0', '24010384.0']], support:2
# pattern:[['14750001.0', '24101003.0']], support:2
# pattern:[['15200012.0']], support:5
# pattern:[['15200012.0', '22111012.0']], support:2
# pattern:[['15200012.0', '15402007.0']], support:2
# pattern:[['15200012.0', '15402007.0', '22111012.0']], support:2
# pattern:[['15200012.0', '15402007.0', '22103005.0']], support:2
# pattern:[['15200012.0', '15402007.0', '22103005.0', '22111012.0']], support:2
# pattern:[['15200012.0', '22103005.0']], support:2
# pattern:[['15200012.0', '22103005.0', '22111012.0']], support:2
# pattern:[['10132003.0']], support:5
# pattern:[['25111051.0']], support:5
# pattern:[['27200170.0']], support:5
# pattern:[['27200170.0', '30380002.0']], support:3
# pattern:[['14515001.0']], support:5
# pattern:[['14515001.0', '24101003.0']], support:2
# pattern:[['14515001.0', '24101003.0', '27300274.0']], support:2
# pattern:[['14515001.0', '22102005.0']], support:2
# pattern:[['14515001.0', '22102005.0', '30380002.0']], support:2
# pattern:[['14515001.0', '22102005.0', '27300274.0']], support:2
# pattern:[['14515001.0', '22102005.0', '27300274.0', '30380002.0']], support:2
# pattern:[['14515001.0', '15114013.0']], support:2
# pattern:[['14515001.0', '15114013.0', '30380002.0']], support:2
# pattern:[['14515001.0', '15114013.0', '27300274.0']], support:2
# pattern:[['14515001.0', '15114013.0', '27300274.0', '30380002.0']], support:2
# pattern:[['14515001.0', '15114013.0', '22102005.0']], support:2
# pattern:[['14515001.0', '15114013.0', '22102005.0', '30380002.0']], support:2
# pattern:[['14515001.0', '15114013.0', '22102005.0', '27300274.0']], support:2
# pattern:[['14515001.0', '15114013.0', '22102005.0', '27300274.0', '30380002.0']], support:2
# pattern:[['14515001.0', '22100010.0']], support:2
# pattern:[['14515001.0', '22100010.0', '24101003.0']], support:2
# pattern:[['14515001.0', '22100010.0', '24101003.0', '27300274.0']], support:2
# pattern:[['14515001.0', '22100010.0', '27300274.0']], support:2
# pattern:[['14515001.0', '27300274.0']], support:3
# pattern:[['14515001.0', '27300274.0', '30380002.0']], support:2
# pattern:[['14515001.0', '30380002.0']], support:4
# pattern:[['10132019.0']], support:5
# pattern:[['22007031.0']], support:5
# pattern:[['22171004.0']], support:5
# pattern:[['22171004.0', '25101044.0']], support:2
# pattern:[['23112013.0']], support:5
# pattern:[['23112013.0', '27410000.0']], support:2
# pattern:[['23112013.0', '30380003.0']], support:2
# pattern:[['23112013.0', '27000576.0']], support:2
# pattern:[['23112013.0', '27000576.0', '27410000.0']], support:2
# pattern:[['27002177.0']], support:5
# pattern:[['27002177.0', '27300274.0']], support:3
# pattern:[['14013009.0']], support:5
# pattern:[['14013009.0', '14072004.0']], support:2
# pattern:[['14013009.0', '15242005.0']], support:2
# pattern:[['14013009.0', '15242005.0', '25101044.0']], support:2
# pattern:[['14013009.0', '25101044.0']], support:2
# pattern:[['14082015.0']], support:5
# pattern:[['14082015.0', '23132068.0']], support:2
# pattern:[['14082015.0', '23132068.0', '27300274.0']], support:2
# pattern:[['14082015.0', '25100108.0']], support:3
# pattern:[['14082015.0', '25100108.0', '27002177.0']], support:2
# pattern:[['14082015.0', '25100108.0', '27002177.0', '27300274.0']], support:2
# pattern:[['14082015.0', '25100108.0', '27002167.0']], support:2
# pattern:[['14082015.0', '25100108.0', '27002167.0', '27300274.0']], support:2
# pattern:[['14082015.0', '25100108.0', '27002167.0', '27002177.0']], support:2
# pattern:[['14082015.0', '25100108.0', '27002167.0', '27002177.0', '27300274.0']], support:2
# pattern:[['14082015.0', '25100108.0', '27300274.0']], support:3
# pattern:[['14082015.0', '27002177.0']], support:3
# pattern:[['14082015.0', '27002177.0', '27300274.0']], support:3
# pattern:[['14082015.0', '27002167.0']], support:3
# pattern:[['14082015.0', '27002167.0', '27300274.0']], support:3
# pattern:[['14082015.0', '27002167.0', '27002177.0']], support:3
# pattern:[['14082015.0', '27002167.0', '27002177.0', '27300274.0']], support:3
# pattern:[['14082015.0', '27300274.0']], support:5
# pattern:[['15230003.0']], support:5
# pattern:[['15230003.0', '27300273.0']], support:2
# pattern:[['15130035.0']], support:5
# pattern:[['14860025.0']], support:5
# pattern:[['22041007.0']], support:5
# pattern:[['25111021.0']], support:5
# pattern:[['25111021.0', '27410000.0']], support:2
# pattern:[['25111021.0', '25111048.0']], support:3
# pattern:[['10132001.0']], support:5
# pattern:[['23113028.0']], support:5
# pattern:[['22671077.0']], support:5
# pattern:[['22671077.0', '30380002.0']], support:2
# pattern:[['22671077.0', '27100542.0']], support:2
# pattern:[['22671077.0', '23110009.0']], support:2
# pattern:[['22671077.0', '23110009.0', '30380002.0']], support:2
# pattern:[['14833003.0']], support:5
# pattern:[['23110190.0']], support:5
# pattern:[['23110190.0', '30380002.0']], support:2
# pattern:[['15004024.0']], support:5
# pattern:[['15004024.0', '15235001.0']], support:2
# pattern:[['22630049.0']], support:5
# pattern:[['22172007.0']], support:5
# pattern:[['22172007.0', '27300274.0']], support:2
# pattern:[['22172007.0', '27002558.0']], support:2
# pattern:[['15110069.0']], support:5
# pattern:[['15110069.0', '27100542.0']], support:2
# pattern:[['15110069.0', '15130027.0']], support:3
# pattern:[['14258011.0']], support:6
# pattern:[['14258011.0', '15230002.0']], support:2
# pattern:[['14258011.0', '15110038.0']], support:2
# pattern:[['14258011.0', '15110043.0']], support:3
# pattern:[['14258011.0', '14513033.0']], support:6
# pattern:[['14258011.0', '14513033.0', '15230002.0']], support:2
# pattern:[['14258011.0', '14513033.0', '15110038.0']], support:2
# pattern:[['14258011.0', '14513033.0', '15110043.0']], support:3
# pattern:[['22190000.0']], support:6
# pattern:[['22190000.0', '22190002.0']], support:2
# pattern:[['22190000.0', '27210006.0']], support:2
# pattern:[['25012012.0']], support:6
# pattern:[['22130016.0']], support:6
# pattern:[['10151002.0']], support:6
# pattern:[['15114008.0']], support:6
# pattern:[['15114008.0', '23110144.0']], support:2
# pattern:[['15114008.0', '22103010.0']], support:2
# pattern:[['15114008.0', '15114037.0']], support:2
# pattern:[['15114008.0', '15114037.0', '15120000.0']], support:2
# pattern:[['15114008.0', '15130006.0']], support:2
# pattern:[['15114008.0', '15120000.0']], support:3
# pattern:[['15114008.0', '15120000.0', '15130006.0']], support:2
# pattern:[['10141040.0']], support:6
# pattern:[['10141040.0', '10141042.0']], support:2
# pattern:[['24010819.0']], support:6
# pattern:[['24010819.0', '30380003.0']], support:2
# pattern:[['10141025.0']], support:6
# pattern:[['10141025.0', '30380003.0']], support:2
# pattern:[['10131002.0']], support:6
# pattern:[['10131002.0', '22030011.0']], support:2
# pattern:[['15112000.0']], support:6
# pattern:[['15112000.0', '27300274.0']], support:2
# pattern:[['15112000.0', '27300274.0', '27300276.0']], support:2
# pattern:[['15112000.0', '27300274.0', '27300276.0', '30380002.0']], support:2
# pattern:[['15112000.0', '27300274.0', '30380002.0']], support:2
# pattern:[['15112000.0', '27300276.0']], support:2
# pattern:[['15112000.0', '27300276.0', '30380002.0']], support:2
# pattern:[['15112000.0', '30380002.0']], support:3
# pattern:[['10119075.0']], support:6
# pattern:[['10119075.0', '27000582.0']], support:2
# pattern:[['10119075.0', '30380003.0']], support:3
# pattern:[['22020006.0']], support:6
# pattern:[['22020006.0', '30380002.0']], support:2
# pattern:[['14091047.0']], support:6
# pattern:[['14091047.0', '30380003.0']], support:2
# pattern:[['24010823.0']], support:6
# pattern:[['10000025.0']], support:6
# pattern:[['10000025.0', '10202000.0']], support:2
# pattern:[['14092021.0']], support:6
# pattern:[['14092021.0', '14092023.0']], support:2
# pattern:[['14092021.0', '30380002.0']], support:3
# pattern:[['14076009.0']], support:6
# pattern:[['14076009.0', '25120016.0']], support:2
# pattern:[['14076009.0', '23110009.0']], support:2
# pattern:[['15121001.0']], support:6
# pattern:[['15130010.0']], support:6
# pattern:[['15130010.0', '30380003.0']], support:3
# pattern:[['10501054.0']], support:6
# pattern:[['27210006.0']], support:6
# pattern:[['15230001.0']], support:6
# pattern:[['15114005.0']], support:6
# pattern:[['15114005.0', '15200001.0']], support:2
# pattern:[['15114005.0', '15200001.0', '30380003.0']], support:2
# pattern:[['15114005.0', '23110009.0']], support:2
# pattern:[['15114005.0', '30380003.0']], support:3
# pattern:[['15232001.0']], support:6
# pattern:[['25005060.0']], support:6
# pattern:[['25005060.0', '27002584.0']], support:2
# pattern:[['25005060.0', '27002584.0', '30380003.0']], support:2
# pattern:[['25005060.0', '30380003.0']], support:2
# pattern:[['25005060.0', '27000577.0']], support:2
# pattern:[['20121037.0']], support:6
# pattern:[['20121037.0', '21021043.0']], support:2
# pattern:[['15402007.0']], support:7
# pattern:[['15402007.0', '22111012.0']], support:2
# pattern:[['15402007.0', '27100542.0']], support:2
# pattern:[['15402007.0', '22103005.0']], support:2
# pattern:[['15402007.0', '22103005.0', '22111012.0']], support:2
# pattern:[['15402007.0', '22500022.0']], support:2
# pattern:[['15402007.0', '22500022.0', '27300274.0']], support:2
# pattern:[['15402007.0', '30380002.0']], support:2
# pattern:[['15402007.0', '27300274.0']], support:3
# pattern:[['23142012.0']], support:7
# pattern:[['10001007.0']], support:7
# pattern:[['10001007.0', '25120014.0']], support:2
# pattern:[['10001007.0', '10131002.0']], support:4
# pattern:[['15115008.0']], support:7
# pattern:[['23110005.0']], support:7
# pattern:[['23110005.0', '23131002.0']], support:2
# pattern:[['23110005.0', '23134003.0']], support:3
# pattern:[['27300281.0']], support:7
# pattern:[['27300281.0', '27410000.0']], support:2
# pattern:[['27300281.0', '27410000.0', '30380002.0']], support:2
# pattern:[['27300281.0', '30380002.0']], support:3
# pattern:[['22008012.0']], support:7
# pattern:[['22008012.0', '23131002.0']], support:2
# pattern:[['14222034.0']], support:7
# pattern:[['14222034.0', '14822002.0']], support:2
# pattern:[['14222034.0', '30380003.0']], support:3
# pattern:[['14222034.0', '15022003.0']], support:3
# pattern:[['23142001.0']], support:7
# pattern:[['15110030.0']], support:7
# pattern:[['15110030.0', '30380003.0']], support:2
# pattern:[['15110030.0', '27002555.0']], support:2
# pattern:[['15202079.0']], support:7
# pattern:[['15202079.0', '24401008.0']], support:2
# pattern:[['15202079.0', '24401008.0', '27002167.0']], support:2
# pattern:[['15202079.0', '25101002.0']], support:2
# pattern:[['15202079.0', '23132068.0']], support:2
# pattern:[['15202079.0', '23131002.0']], support:2
# pattern:[['15202079.0', '23131002.0', '27002167.0']], support:2
# pattern:[['15202079.0', '23131002.0', '24401008.0']], support:2
# pattern:[['15202079.0', '23131002.0', '24401008.0', '27002167.0']], support:2
# pattern:[['15202079.0', '27002173.0']], support:2
# pattern:[['15202079.0', '23110009.0']], support:3
# pattern:[['15202079.0', '27002167.0']], support:3
# pattern:[['15202079.0', '27002167.0', '27002173.0']], support:2
# pattern:[['14060002.0']], support:7
# pattern:[['14060002.0', '23120001.0']], support:2
# pattern:[['14060002.0', '23110144.0']], support:2
# pattern:[['14060002.0', '15114008.0']], support:2
# pattern:[['14060002.0', '15114000.0']], support:2
# pattern:[['14060002.0', '15114000.0', '23120001.0']], support:2
# pattern:[['14060002.0', '15235001.0']], support:3
# pattern:[['11300223.0']], support:7
# pattern:[['22701014.0']], support:7
# pattern:[['22701014.0', '30380003.0']], support:2
# pattern:[['27002169.0']], support:7
# pattern:[['27002169.0', '30380002.0']], support:2
# pattern:[['27002169.0', '30380001.0']], support:2
# pattern:[['25130010.0']], support:7
# pattern:[['25130010.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27000582.0']], support:2
# pattern:[['25130010.0', '27000582.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27000582.0', '27410000.0']], support:2
# pattern:[['25130010.0', '27000582.0', '27410000.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27000581.0']], support:2
# pattern:[['25130010.0', '27000581.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27000581.0', '27410000.0']], support:2
# pattern:[['25130010.0', '27000581.0', '27410000.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27000581.0', '27000582.0']], support:2
# pattern:[['25130010.0', '27000581.0', '27000582.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27000581.0', '27000582.0', '27410000.0']], support:2
# pattern:[['25130010.0', '27000581.0', '27000582.0', '27410000.0', '30380002.0']], support:2
# pattern:[['25130010.0', '27410000.0']], support:3
# pattern:[['25130010.0', '27410000.0', '30380002.0']], support:2
# pattern:[['27300282.0']], support:7
# pattern:[['27300282.0', '27410000.0']], support:3
# pattern:[['14513033.0']], support:7
# pattern:[['14513033.0', '15230002.0']], support:2
# pattern:[['14513033.0', '15110038.0']], support:2
# pattern:[['14513033.0', '15110043.0']], support:3
# pattern:[['27300276.0']], support:7
# pattern:[['27300276.0', '30380002.0']], support:2
# pattern:[['27300276.0', '27300281.0']], support:2
# pattern:[['14013010.0']], support:7
# pattern:[['14013010.0', '23120001.0']], support:2
# pattern:[['14013010.0', '23120001.0', '30380003.0']], support:2
# pattern:[['14013010.0', '30380003.0']], support:2
# pattern:[['10133001.0']], support:7
# pattern:[['10133001.0', '27000581.0']], support:2
# pattern:[['10133001.0', '30380002.0']], support:2
# pattern:[['10133001.0', '30380003.0']], support:2
# pattern:[['15231005.0']], support:7
# pattern:[['15231005.0', '25101044.0']], support:2
# pattern:[['15231005.0', '27000582.0']], support:2
# pattern:[['15231005.0', '15231006.0']], support:2
# pattern:[['15110028.0']], support:7
# pattern:[['15110028.0', '27000582.0']], support:2
# pattern:[['15110028.0', '27000582.0', '27300273.0']], support:2
# pattern:[['15110028.0', '30380003.0']], support:2
# pattern:[['15110028.0', '27300273.0']], support:2
# pattern:[['25100108.0']], support:7
# pattern:[['25100108.0', '27002177.0']], support:2
# pattern:[['25100108.0', '27002177.0', '27300274.0']], support:2
# pattern:[['25100108.0', '27002167.0']], support:2
# pattern:[['25100108.0', '27002167.0', '27300274.0']], support:2
# pattern:[['25100108.0', '27002167.0', '27002177.0']], support:2
# pattern:[['25100108.0', '27002167.0', '27002177.0', '27300274.0']], support:2
# pattern:[['25100108.0', '27300276.0']], support:2
# pattern:[['25100108.0', '27300274.0']], support:5
# pattern:[['25100108.0', '27300274.0', '27300276.0']], support:2
# pattern:[['15110085.0']], support:8
# pattern:[['15110085.0', '22036000.0']], support:2
# pattern:[['15110085.0', '27000582.0']], support:2
# pattern:[['15110085.0', '30380003.0']], support:2
# pattern:[['25110012.0']], support:8
# pattern:[['25110012.0', '27000582.0']], support:2
# pattern:[['25110012.0', '27410000.0']], support:2
# pattern:[['25110012.0', '27000573.0']], support:2
# pattern:[['15110044.0']], support:8
# pattern:[['15110044.0', '27200924.0']], support:2
# pattern:[['27400145.0']], support:8
# pattern:[['27400145.0', '30380003.0']], support:2
# pattern:[['27400145.0', '34225051.0']], support:2
# pattern:[['27400145.0', '30380002.0']], support:3
# pattern:[['22111012.0']], support:8
# pattern:[['22111012.0', '30380002.0']], support:2
# pattern:[['22111012.0', '27300274.0']], support:3
# pattern:[['22111012.0', '27300274.0', '30380002.0']], support:2
# pattern:[['22111012.0', '22111031.0']], support:3
# pattern:[['22001013.0']], support:8
# pattern:[['22001013.0', '27000582.0']], support:2
# pattern:[['22001013.0', '30380003.0']], support:2
# pattern:[['22008021.0']], support:8
# pattern:[['22008021.0', '22102014.0']], support:2
# pattern:[['22008021.0', '22102014.0', '27410000.0']], support:2
# pattern:[['22008021.0', '27410000.0']], support:2
# ...
# pattern:[['25012012.0']], support:11
# pattern:[['11532011.0']], support:11
# pattern:[['10151002.0']], support:11
# pattern:[['10141044.0']], support:11
# pattern:[['10000011.0']], support:11
# pattern:[['24010017.0']], support:11
# pattern:[['22610103.0']], support:11
# pattern:[['24000373.0']], support:11
# pattern:[['14076012.0']], support:11
# pattern:[['22111008.0']], support:11
# pattern:[['14403083.0']], support:11
# pattern:[['15231004.0']], support:11
# pattern:[['24010823.0']], support:11
# pattern:[['27240000.0']], support:11
# pattern:[['10140002.0']], support:11
# pattern:[['14860022.0']], support:11
# pattern:[['14860017.0']], support:11
# pattern:[['22034026.0']], support:11
# pattern:[['15004024.0']], support:11
# pattern:[['22172003.0']], support:11
# pattern:[['15110069.0']], support:11
# pattern:[['15200008.0']], support:12
# pattern:[['27002188.0']], support:12
# pattern:[['15231007.0']], support:12
# pattern:[['22604000.0']], support:12
# pattern:[['22172008.0']], support:12
# pattern:[['15115002.0']], support:12
# pattern:[['27002174.0']], support:12
# pattern:[['15130034.0']], support:12
# pattern:[['22802001.0']], support:12
# pattern:[['14860020.0']], support:12
# pattern:[['22111001.0']], support:12
# pattern:[['22172000.0']], support:12
# pattern:[['15110018.0']], support:12
# pattern:[['22600000.0']], support:12
# pattern:[['24010000.0']], support:12
# pattern:[['15230004.0']], support:12
# pattern:[['22102001.0']], support:12
# pattern:[['32416009.0']], support:12
# pattern:[['27200925.0']], support:12
# pattern:[['14130055.0']], support:12
# pattern:[['27400126.0']], support:12
# pattern:[['22103011.0']], support:13
# pattern:[['22103004.0']], support:13
# pattern:[['24101000.0']], support:13
# pattern:[['25130010.0']], support:13
# pattern:[['15111010.0']], support:13
# pattern:[['22130017.0']], support:13
# pattern:[['22008009.0']], support:13
# pattern:[['24010380.0']], support:13
# pattern:[['25111051.0']], support:13
# pattern:[['22103010.0']], support:13
# pattern:[['27300282.0']], support:13
# pattern:[['14076009.0']], support:13
# pattern:[['15114013.0']], support:13
# pattern:[['15110004.0']], support:13
# pattern:[['23110144.0']], support:13
# pattern:[['15110043.0']], support:13
# pattern:[['27410005.0']], support:14
# pattern:[['15110080.0']], support:14
# pattern:[['22600002.0']], support:14
# pattern:[['10000006.0']], support:14
# pattern:[['22007031.0']], support:14
# pattern:[['22171004.0']], support:14
# pattern:[['22001038.0']], support:14
# pattern:[['22102013.0']], support:14
# pattern:[['20121037.0']], support:14
# pattern:[['27300281.0']], support:15
# pattern:[['15110015.0']], support:15
# pattern:[['22021260.0']], support:15
# pattern:[['15114010.0']], support:15
# pattern:[['23134002.0']], support:15
# pattern:[['25120014.0']], support:15
# pattern:[['25120014.0', '25120016.0']], support:8
# pattern:[['15200004.0']], support:15
# pattern:[['10141038.0']], support:15
# pattern:[['22000049.0']], support:16
# pattern:[['15235001.0']], support:16
# pattern:[['22034000.0']], support:16
# pattern:[['22130007.0']], support:16
# pattern:[['27300276.0']], support:16
# pattern:[['25101002.0']], support:16
# pattern:[['21801125.0']], support:17
# pattern:[['15231005.0']], support:17
# pattern:[['23132063.0']], support:17
# pattern:[['25101046.0']], support:17
# pattern:[['27002555.0']], support:17
# pattern:[['10141042.0']], support:17
# pattern:[['22020002.0']], support:17
# pattern:[['24010809.0']], support:17
# pattern:[['24010819.0']], support:17
# pattern:[['23110006.0']], support:17
# pattern:[['22130000.0']], support:17
# pattern:[['22190000.0']], support:18
# pattern:[['22630009.0']], support:18
# pattern:[['15130006.0']], support:18
# pattern:[['24010384.0']], support:18
# pattern:[['23121052.0']], support:18
# pattern:[['22102009.0']], support:18
# pattern:[['15230001.0']], support:18
# pattern:[['22008012.0']], support:19
# pattern:[['24101002.0']], support:19
# pattern:[['24101002.0', '30380003.0']], support:8
# pattern:[['23113027.0']], support:19
# pattern:[['22111031.0']], support:20
# pattern:[['27410001.0']], support:20
# pattern:[['22001006.0']], support:20
# pattern:[['22102004.0']], support:20
# pattern:[['27410002.0']], support:21
# pattern:[['27200938.0']], support:21
# pattern:[['22100000.0']], support:21
# pattern:[['15202044.0']], support:21
# pattern:[['22101000.0']], support:22
# pattern:[['15115003.0']], support:22
# pattern:[['22002239.0']], support:22
# pattern:[['22020006.0']], support:23
# pattern:[['27400855.0']], support:23
# pattern:[['15232001.0']], support:23
# pattern:[['15130009.0']], support:24
# pattern:[['22111012.0']], support:25
# pattern:[['22111012.0', '30380002.0']], support:9
# pattern:[['22030011.0']], support:25
# pattern:[['22103001.0']], support:26
# pattern:[['24101006.0']], support:26
# pattern:[['22103005.0']], support:26
# pattern:[['15130035.0']], support:26
# pattern:[['22008019.0']], support:26
# pattern:[['22008019.0', '30380003.0']], support:10
# pattern:[['27000574.0']], support:27
# pattern:[['27000574.0', '30380003.0']], support:8
# pattern:[['22102000.0']], support:27
# pattern:[['22002240.0']], support:27
# pattern:[['27410044.0']], support:27
# pattern:[['27410044.0', '30380002.0']], support:9
# pattern:[['21021043.0']], support:28
# pattern:[['30380001.0']], support:28
# pattern:[['22008020.0']], support:28
# pattern:[['22008020.0', '30380003.0']], support:12
# pattern:[['15114015.0']], support:29
# pattern:[['22008021.0']], support:30
# pattern:[['22008021.0', '30380003.0']], support:10
# pattern:[['22701014.0']], support:30
# pattern:[['25101011.0']], support:31
# pattern:[['25101011.0', '30380003.0']], support:8
# pattern:[['22170001.0']], support:31
# pattern:[['22170001.0', '30380002.0']], support:10
# pattern:[['22101001.0']], support:32
# pattern:[['22035000.0']], support:33
# pattern:[['22035000.0', '30380003.0']], support:10
# pattern:[['27000576.0']], support:33
# pattern:[['15110071.0']], support:33
# pattern:[['15110071.0', '30380003.0']], support:8
# pattern:[['23132061.0']], support:35
# pattern:[['22100010.0']], support:35
# pattern:[['27000573.0']], support:36
# pattern:[['22601000.0']], support:36
# pattern:[['15119001.0']], support:37
# pattern:[['25120036.0']], support:37
# pattern:[['25120036.0', '30380003.0']], support:9
# pattern:[['27100542.0']], support:40
# pattern:[['27000581.0']], support:40
# pattern:[['27000581.0', '30380003.0']], support:14
# pattern:[['15200007.0']], support:41
# pattern:[['15200007.0', '30380002.0']], support:12
# pattern:[['22111004.0']], support:41
# pattern:[['22111004.0', '30380002.0']], support:10
# pattern:[['15110001.0']], support:41
# pattern:[['25111048.0']], support:42
# pattern:[['23134003.0']], support:44
# pattern:[['23134003.0', '30380003.0']], support:11
# pattern:[['23131002.0']], support:44
# pattern:[['23131002.0', '30380003.0']], support:8
# pattern:[['23131002.0', '23134003.0']], support:9
# pattern:[['23110007.0']], support:45
# pattern:[['23110007.0', '30380002.0']], support:10
# pattern:[['23110007.0', '30380003.0']], support:10
# pattern:[['27410003.0']], support:45
# pattern:[['27300273.0']], support:51
# pattern:[['27300273.0', '30380003.0']], support:8
# pattern:[['27300273.0', '27410000.0']], support:10
# pattern:[['15130027.0']], support:51
# pattern:[['15130027.0', '30380003.0']], support:12
# pattern:[['15130027.0', '30380002.0']], support:13
# pattern:[['22500022.0']], support:52
# pattern:[['22500022.0', '23110009.0']], support:8
# pattern:[['23120001.0']], support:57
# pattern:[['23120001.0', '30380003.0']], support:13
# pattern:[['23132068.0']], support:59
# pattern:[['23132068.0', '30380003.0']], support:9
# pattern:[['27300274.0']], support:62
# pattern:[['27300274.0', '27300276.0']], support:8
# pattern:[['27300274.0', '30380002.0']], support:8
# pattern:[['27300274.0', '30380003.0']], support:10
# pattern:[['27200924.0']], support:65
# pattern:[['25120016.0']], support:72
# pattern:[['25120016.0', '30380002.0']], support:13
# pattern:[['25120016.0', '30380003.0']], support:13
# pattern:[['25101044.0']], support:76
# pattern:[['25101044.0', '25120016.0']], support:8
# pattern:[['25101044.0', '30380003.0']], support:9
# pattern:[['23110001.0']], support:78
# pattern:[['23110001.0', '30380002.0']], support:8
# pattern:[['23110001.0', '30380003.0']], support:9
# pattern:[['23110001.0', '23110009.0']], support:10
# pattern:[['22102005.0']], support:80
# pattern:[['22102005.0', '23110009.0']], support:8
# pattern:[['22102005.0', '30380003.0']], support:15
# pattern:[['22102005.0', '30380002.0']], support:16
# pattern:[['22102005.0', '22102014.0']], support:18
# pattern:[['22102014.0']], support:97
# pattern:[['22102014.0', '27410000.0']], support:8
# pattern:[['22102014.0', '23110009.0']], support:9
# pattern:[['22102014.0', '22111004.0']], support:11
# pattern:[['22102014.0', '30380003.0']], support:19
# pattern:[['22102014.0', '30380002.0']], support:20
# pattern:[['27000582.0']], support:100
# pattern:[['27000582.0', '30380003.0']], support:8
# pattern:[['27000582.0', '27410000.0']], support:15
# pattern:[['27410000.0']], support:107
# pattern:[['27410000.0', '30380003.0']], support:16
# pattern:[['27410000.0', '30380002.0']], support:17
# pattern:[['22036000.0']], support:111
# pattern:[['22036000.0', '22111004.0']], support:8
# pattern:[['22036000.0', '22102005.0']], support:9
# pattern:[['22036000.0', '22102014.0']], support:9
# pattern:[['22036000.0', '23110009.0']], support:13
# pattern:[['22036000.0', '30380002.0']], support:19
# pattern:[['22036000.0', '30380003.0']], support:29
# pattern:[['23110009.0']], support:176
# pattern:[['23110009.0', '23131002.0']], support:9
# pattern:[['23110009.0', '25120016.0']], support:9
# pattern:[['23110009.0', '23132068.0']], support:9
# pattern:[['23110009.0', '25120036.0']], support:9
# pattern:[['23110009.0', '25101044.0']], support:11
# pattern:[['23110009.0', '27410000.0']], support:13
# pattern:[['23110009.0', '23134003.0']], support:15
# pattern:[['23110009.0', '30380002.0']], support:24
# pattern:[['23110009.0', '30380003.0']], support:33
# pattern:[['30380002.0']], support:227
# pattern:[['30380002.0', '30380003.0']], support:10
# pattern:[['30380003.0']], support:393
#
# min_support = 16:
# pattern:[['22000049.0']], support:16
# pattern:[['15235001.0']], support:16
# pattern:[['22034000.0']], support:16
# pattern:[['22130007.0']], support:16
# pattern:[['27300276.0']], support:16
# pattern:[['25101002.0']], support:16
# pattern:[['21801125.0']], support:17
# pattern:[['15231005.0']], support:17
# pattern:[['23132063.0']], support:17
# pattern:[['25101046.0']], support:17
# pattern:[['27002555.0']], support:17
# pattern:[['10141042.0']], support:17
# pattern:[['22020002.0']], support:17
# pattern:[['24010809.0']], support:17
# pattern:[['24010819.0']], support:17
# pattern:[['23110006.0']], support:17
# pattern:[['22130000.0']], support:17
# pattern:[['22190000.0']], support:18
# pattern:[['22630009.0']], support:18
# pattern:[['15130006.0']], support:18
# pattern:[['24010384.0']], support:18
# pattern:[['23121052.0']], support:18
# pattern:[['22102009.0']], support:18
# pattern:[['15230001.0']], support:18
# pattern:[['22008012.0']], support:19
# pattern:[['24101002.0']], support:19
# pattern:[['23113027.0']], support:19
# pattern:[['22111031.0']], support:20
# pattern:[['27410001.0']], support:20
# pattern:[['22001006.0']], support:20
# pattern:[['22102004.0']], support:20
# pattern:[['27410002.0']], support:21
# pattern:[['27200938.0']], support:21
# pattern:[['22100000.0']], support:21
# pattern:[['15202044.0']], support:21
# pattern:[['22101000.0']], support:22
# pattern:[['15115003.0']], support:22
# pattern:[['22002239.0']], support:22
# pattern:[['22020006.0']], support:23
# pattern:[['27400855.0']], support:23
# pattern:[['15232001.0']], support:23
# pattern:[['15130009.0']], support:24
# pattern:[['22111012.0']], support:25
# pattern:[['22030011.0']], support:25
# pattern:[['22103001.0']], support:26
# pattern:[['24101006.0']], support:26
# pattern:[['22103005.0']], support:26
# pattern:[['15130035.0']], support:26
# pattern:[['22008019.0']], support:26
# pattern:[['27000574.0']], support:27
# pattern:[['22102000.0']], support:27
# pattern:[['22002240.0']], support:27
# pattern:[['27410044.0']], support:27
# pattern:[['21021043.0']], support:28
# pattern:[['30380001.0']], support:28
# pattern:[['22008020.0']], support:28
# pattern:[['15114015.0']], support:29
# pattern:[['22008021.0']], support:30
# pattern:[['22701014.0']], support:30
# pattern:[['25101011.0']], support:31
# pattern:[['22170001.0']], support:31
# pattern:[['22101001.0']], support:32
# pattern:[['22035000.0']], support:33
# pattern:[['27000576.0']], support:33
# pattern:[['15110071.0']], support:33
# pattern:[['23132061.0']], support:35
# pattern:[['22100010.0']], support:35
# pattern:[['27000573.0']], support:36
# pattern:[['22601000.0']], support:36
# pattern:[['15119001.0']], support:37
# pattern:[['25120036.0']], support:37
# pattern:[['27100542.0']], support:40
# pattern:[['27000581.0']], support:40
# pattern:[['15200007.0']], support:41
# pattern:[['22111004.0']], support:41
# pattern:[['15110001.0']], support:41
# pattern:[['25111048.0']], support:42
# pattern:[['23134003.0']], support:44
# pattern:[['23131002.0']], support:44
# pattern:[['23110007.0']], support:45
# pattern:[['27410003.0']], support:45
# pattern:[['27300273.0']], support:51
# pattern:[['15130027.0']], support:51
# pattern:[['22500022.0']], support:52
# pattern:[['23120001.0']], support:57
# pattern:[['23132068.0']], support:59
# pattern:[['27300274.0']], support:62
# pattern:[['27200924.0']], support:65
# pattern:[['25120016.0']], support:72
# pattern:[['25101044.0']], support:76
# pattern:[['23110001.0']], support:78
# pattern:[['22102005.0']], support:80
# pattern:[['22102005.0', '30380002.0']], support:16
# pattern:[['22102005.0', '22102014.0']], support:18
# pattern:[['22102014.0']], support:97
# pattern:[['22102014.0', '30380003.0']], support:19
# pattern:[['22102014.0', '30380002.0']], support:20
# pattern:[['27000582.0']], support:100
# pattern:[['27410000.0']], support:107
# pattern:[['27410000.0', '30380003.0']], support:16
# pattern:[['27410000.0', '30380002.0']], support:17
# pattern:[['22036000.0']], support:111
# pattern:[['22036000.0', '30380002.0']], support:19
# pattern:[['22036000.0', '30380003.0']], support:29
# pattern:[['23110009.0']], support:176
# pattern:[['23110009.0', '30380002.0']], support:24
# pattern:[['23110009.0', '30380003.0']], support:33
# pattern:[['30380002.0']], support:227
# pattern:[['30380003.0']], support:393
#
# min_support = 32:
# pattern:[['22101001.0']], support:32
# pattern:[['22035000.0']], support:33
# pattern:[['27000576.0']], support:33
# pattern:[['15110071.0']], support:33
# pattern:[['23132061.0']], support:35
# pattern:[['22100010.0']], support:35
# pattern:[['27000573.0']], support:36
# pattern:[['22601000.0']], support:36
# pattern:[['15119001.0']], support:37
# pattern:[['25120036.0']], support:37
# pattern:[['27100542.0']], support:40
# pattern:[['27000581.0']], support:40
# pattern:[['15200007.0']], support:41
# pattern:[['22111004.0']], support:41
# pattern:[['15110001.0']], support:41
# pattern:[['25111048.0']], support:42
# pattern:[['23134003.0']], support:44
# pattern:[['23131002.0']], support:44
# pattern:[['23110007.0']], support:45
# pattern:[['27410003.0']], support:45
# pattern:[['27300273.0']], support:51
# pattern:[['15130027.0']], support:51
# pattern:[['22500022.0']], support:52
# pattern:[['23120001.0']], support:57
# pattern:[['23132068.0']], support:59
# pattern:[['27300274.0']], support:62
# pattern:[['27200924.0']], support:65
# pattern:[['25120016.0']], support:72
# pattern:[['25101044.0']], support:76
# pattern:[['23110001.0']], support:78
# pattern:[['22102005.0']], support:80
# pattern:[['22102014.0']], support:97
# pattern:[['27000582.0']], support:100
# pattern:[['27410000.0']], support:107
# pattern:[['22036000.0']], support:111
# pattern:[['23110009.0']], support:176
# pattern:[['23110009.0', '30380003.0']], support:33
# pattern:[['30380002.0']], support:227
# pattern:[['30380003.0']], support:393
#
# min_support = 64:
# pattern:[['27200924.0']], support:65
# pattern:[['25120016.0']], support:72
# pattern:[['25101044.0']], support:76
# pattern:[['23110001.0']], support:78
# pattern:[['22102005.0']], support:80
# pattern:[['22102014.0']], support:97
# pattern:[['27000582.0']], support:100
# pattern:[['27410000.0']], support:107
# pattern:[['22036000.0']], support:111
# pattern:[['23110009.0']], support:176
# pattern:[['30380002.0']], support:227
# pattern:[['30380003.0']], support:393
