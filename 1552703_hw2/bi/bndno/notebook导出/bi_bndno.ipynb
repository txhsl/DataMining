# %%
# PrefixSpan

import sys
import pandas as pd
import numpy as np

PLACE_HOLDER = '_'

def input():

    # file input
    data = pd.read_csv('trade.csv', usecols=['uid', 'vipno', 'sldat', 'bndno'])
    data['timestamp'] = pd.to_datetime(data['sldat'])

    # sort 
    data.sort_values(['vipno','timestamp'],ascending=[1,1],inplace=True) 

    # make groups 
    data['rank'] = data['timestamp'].groupby(data['vipno']).rank(ascending=0,method='first')

    # take top 60% in every group
    grouped = data.groupby(['vipno'], as_index = True).apply(lambda x: x[x['rank'] <= (0.6 * x['rank'].max())])

    # convert
    data_set = grouped.drop(['rank', 'timestamp', 'sldat', 'vipno'], axis=1).reset_index(drop=True)

    # merge by uid
    data_set['value'] = data_set['bndno']
    data_set = data_set.pivot_table(data_set, index=['uid'], columns=['bndno'])

    return data_set.fillna(0)

def input_new():

    # file input
    data = pd.read_csv('trade_new.csv', usecols=['uid', 'vipno', 'sldatime', 'bndno'])
    data['timestamp'] = pd.to_datetime(data['sldatime'])

    # sort 
    data.sort_values(['vipno','timestamp'],ascending=[1,1],inplace=True) 

    # make groups 
    data['rank'] = data['timestamp'].groupby(data['vipno']).rank(ascending=0,method='first')

    # take top 60% in every group
    grouped = data.groupby(['vipno'], as_index = True).apply(lambda x: x[x['rank'] <= (0.6 * x['rank'].max())])

    # convert
    data_set = grouped.drop(['rank', 'timestamp', 'sldatime', 'vipno'], axis=1).reset_index(drop=True)

    # merge by uid
    data_set['value'] = data_set['bndno']
    data_set = data_set.pivot_table(data_set, index=['uid'], columns=['bndno'])

    return data_set.fillna(0)

def createInitSet(data_set):  

    # clear all 0
    data_array = data_set.as_matrix()
    data_dok = []
    for row in data_array:
        s = []
        s.append([str(x) for x in row if x != 0.0])
        data_dok.append(s)

    return data_dok

# %%
class SquencePattern:
    def __init__(self, squence, support):
        self.squence = []
        for s in squence:
            self.squence.append(list(s))
        self.support = support

    def append(self, p):
        if p.squence[0][0] == PLACE_HOLDER:
            first_e = p.squence[0]
            first_e.remove(PLACE_HOLDER)
            self.squence[-1].extend(first_e)
            self.squence.extend(p.squence[1:])
        else:
            self.squence.extend(p.squence)
        self.support = min(self.support, p.support)


def prefixSpan(pattern, S, threshold):
    patterns = []
    f_list = frequent_items(S, pattern, threshold)
	
    for i in f_list:
        p = SquencePattern(pattern.squence, pattern.support)
        p.append(i)
        patterns.append(p)
        
        
        p_S = build_projected_database(S, p)
        p_patterns = prefixSpan(p, p_S, threshold)
        patterns.extend(p_patterns)
    return patterns


def frequent_items(S, pattern, threshold):
    items = {}
    _items = {}
    f_list = []
    if S is None or len(S) == 0:
        return []

    if len(pattern.squence) != 0:
        last_e = pattern.squence[-1]
    else:
        last_e = []
    for s in S:
        #class 1
        is_prefix = True
        for item in last_e:
            if item not in s[0]:
                is_prefix = False
                break
        if is_prefix and len(last_e) > 0:
            index = s[0].index(last_e[-1])
            if index < len(s[0]) - 1:
                for item in s[0][index + 1:]:
                    if item in _items:
                        _items[item] += 1
                    else:
                        _items[item] = 1

        #class 2
        if PLACE_HOLDER in s[0]:
            for item in s[0][1:]:
                if item in _items:
                    _items[item] += 1
                else:
                    _items[item] = 1
            s = s[1:]

        #class 3
        counted = []
        for element in s:
            for item in element:
                if item not in counted:
                    counted.append(item)
                    if item in items:
                        items[item] += 1
                    else:
                        items[item] = 1

    f_list.extend([SquencePattern([[PLACE_HOLDER, k]], v)
                    for k, v in _items.iteritems()
                    if v >= threshold])
    f_list.extend([SquencePattern([[k]], v)
                   for k, v in items.iteritems()
                   if v >= threshold])
    sorted_list = sorted(f_list, key=lambda p: p.support)
    return sorted_list  
    


def build_projected_database(S, pattern):
    """
    suppose S is projected database base on pattern's prefix,
    so we only need to use the last element in pattern to
    build projected database
    """
    p_S = []
    last_e = pattern.squence[-1]
    last_item = last_e[-1]
    for s in S:
        p_s = []
        for element in s:
            is_prefix = False
            if PLACE_HOLDER in element:
                if last_item in element and len(pattern.squence[-1]) > 1:
                    is_prefix = True
            else:
                is_prefix = True
                for item in last_e:
                    if item not in element:
                        is_prefix = False
                        break

            if is_prefix:
                e_index = s.index(element)
                i_index = element.index(last_item)
                if i_index == len(element) - 1:
                    p_s = s[e_index + 1:]
                else:
                    p_s = s[e_index:]
                    index = element.index(last_item)
                    e = element[i_index:]
                    e[0] = PLACE_HOLDER
                    p_s[0] = e
                break
        if len(p_s) != 0:
            p_S.append(p_s)

    return p_S


def print_patterns(patterns):
    for p in patterns:
        print("pattern:{0}, support:{1}".format(p.squence, p.support))

# %%
if __name__ == "__main__":
    
    S = createInitSet(input())

    for min_support in [2,4,8,16,32,64]:
        print "\nmin_support = %d: "%min_support
        patterns = prefixSpan(SquencePattern([], sys.maxint), S, min_support)
        print_patterns(patterns)

    S = createInitSet(input_new())

    for min_support in [2,4,8,16,32,64]:
        print "\nmin_support = %d: "%min_support
        patterns = prefixSpan(SquencePattern([], sys.maxint), S, min_support)
        print_patterns(patterns)
# Out:
# min_support = 2:
# pattern:[['11008.0']], support:2
# pattern:[['34060.0']], support:2
# pattern:[['14830.0']], support:2
# pattern:[['14556.0']], support:2
# pattern:[['34039.0']], support:2
# pattern:[['14834.0']], support:2
# pattern:[['14558.0']], support:2
# pattern:[['14445.0']], support:2
# pattern:[['14167.0']], support:2
# pattern:[['14121.0']], support:2
# pattern:[['14076.0']], support:2
# pattern:[['11131.0']], support:2
# pattern:[['11119.0']], support:2
# pattern:[['10005.0']], support:2
# pattern:[['14123.0']], support:2
# pattern:[['14123.0', '14362.0']], support:2
# pattern:[['11327.0']], support:2
# pattern:[['10154.0']], support:2
# pattern:[['14246.0']], support:2
# pattern:[['30727.0']], support:2
# pattern:[['14010.0']], support:2
# pattern:[['14010.0', '30248.0']], support:2
# pattern:[['14703.0']], support:2
# pattern:[['14703.0', '14753.0']], support:2
# pattern:[['14020.0']], support:2
# pattern:[['14736.0']], support:2
# pattern:[['14784.0']], support:2
# pattern:[['14784.0', '15094.0']], support:2
# pattern:[['14784.0', '15052.0']], support:2
# pattern:[['14784.0', '15052.0', '15094.0']], support:2
# pattern:[['14784.0', '14785.0']], support:2
# pattern:[['14784.0', '14785.0', '15094.0']], support:2
# pattern:[['14784.0', '14785.0', '15052.0']], support:2
# pattern:[['14784.0', '14785.0', '15052.0', '15094.0']], support:2
# pattern:[['10036.0']], support:2
# pattern:[['10043.0']], support:2
# pattern:[['10628.0']], support:2
# pattern:[['30216.0']], support:2
# pattern:[['14301.0']], support:2
# pattern:[['14301.0', '14810.0']], support:2
# pattern:[['15653.0']], support:2
# pattern:[['30352.0']], support:2
# pattern:[['30186.0']], support:2
# pattern:[['10053.0']], support:2
# pattern:[['10703.0']], support:2
# pattern:[['30253.0']], support:2
# pattern:[['14539.0']], support:2
# pattern:[['14539.0', '14622.0']], support:2
# pattern:[['14539.0', '14622.0', '30248.0']], support:2
# pattern:[['14539.0', '30248.0']], support:2
# pattern:[['11156.0']], support:2
# pattern:[['34003.0']], support:2
# pattern:[['11011.0']], support:2
# pattern:[['11291.0']], support:2
# pattern:[['11291.0', '30248.0']], support:2
# pattern:[['31027.0']], support:2
# pattern:[['14293.0']], support:2
# pattern:[['11146.0']], support:2
# pattern:[['14102.0']], support:2
# pattern:[['11144.0']], support:2
# pattern:[['15548.0']], support:2
# pattern:[['14118.0']], support:2
# pattern:[['14247.0']], support:2
# pattern:[['11097.0']], support:2
# pattern:[['11106.0']], support:2
# pattern:[['11049.0']], support:2
# pattern:[['15564.0']], support:2
# pattern:[['14444.0']], support:2
# pattern:[['14835.0']], support:2
# pattern:[['30804.0']], support:2
# pattern:[['14116.0']], support:2
# pattern:[['14565.0']], support:2
# pattern:[['10103.0']], support:2
# pattern:[['32183.0']], support:2
# pattern:[['11322.0']], support:2
# pattern:[['14033.0']], support:2
# pattern:[['11209.0']], support:2
# pattern:[['15666.0']], support:2
# pattern:[['14719.0']], support:2
# pattern:[['14488.0']], support:2
# pattern:[['10702.0']], support:2
# pattern:[['33046.0']], support:2
# pattern:[['14397.0']], support:2
# pattern:[['14314.0']], support:2
# pattern:[['14314.0', '14393.0']], support:2
# pattern:[['34129.0']], support:2
# pattern:[['10715.0']], support:2
# pattern:[['14386.0']], support:2
# pattern:[['14612.0']], support:2
# pattern:[['14279.0']], support:2
# pattern:[['14279.0', '15052.0']], support:2
# pattern:[['14279.0', '15052.0', '30248.0']], support:2
# pattern:[['14279.0', '30248.0']], support:2
# pattern:[['14279.0', '14753.0']], support:2
# pattern:[['14279.0', '14753.0', '15052.0']], support:2
# pattern:[['14279.0', '14753.0', '15052.0', '30248.0']], support:2
# pattern:[['14279.0', '14753.0', '30248.0']], support:2
# pattern:[['14197.0']], support:2
# pattern:[['30123.0']], support:2
# pattern:[['14203.0']], support:2
# pattern:[['14203.0', '14366.0']], support:2
# pattern:[['15003.0']], support:2
# pattern:[['15003.0', '30248.0']], support:2
# pattern:[['15001.0']], support:2
# pattern:[['11036.0']], support:2
# pattern:[['14785.0']], support:2
# pattern:[['14785.0', '15094.0']], support:2
# pattern:[['14785.0', '15052.0']], support:2
# pattern:[['14785.0', '15052.0', '15094.0']], support:2
# pattern:[['11284.0']], support:2
# pattern:[['14421.0']], support:2
# pattern:[['10608.0']], support:3
# pattern:[['10608.0', '10659.0']], support:2
# pattern:[['14288.0']], support:3
# pattern:[['14288.0', '30248.0']], support:2
# pattern:[['14740.0']], support:3
# pattern:[['34801.0']], support:3
# pattern:[['14088.0']], support:3
# pattern:[['14088.0', '30248.0']], support:2
# pattern:[['30060.0']], support:3
# pattern:[['14449.0']], support:3
# pattern:[['10069.0']], support:3
# pattern:[['10045.0']], support:3
# pattern:[['31017.0']], support:3
# pattern:[['10209.0']], support:3
# pattern:[['10209.0', '30248.0']], support:3
# pattern:[['15074.0']], support:3
# pattern:[['15074.0', '30248.0']], support:2
# pattern:[['15002.0']], support:3
# pattern:[['11130.0']], support:3
# pattern:[['11130.0', '30248.0']], support:2
# pattern:[['11130.0', '15092.0']], support:2
# pattern:[['11130.0', '15092.0', '30248.0']], support:2
# pattern:[['14623.0']], support:3
# pattern:[['14623.0', '15039.0']], support:2
# pattern:[['10726.0']], support:3
# pattern:[['14200.0']], support:3
# pattern:[['14422.0']], support:3
# pattern:[['14422.0', '30248.0']], support:2
# pattern:[['14794.0']], support:3
# pattern:[['32133.0']], support:3
# pattern:[['10038.0']], support:3
# pattern:[['10038.0', '15009.0']], support:2
# pattern:[['14753.0']], support:3
# pattern:[['14753.0', '15052.0']], support:2
# pattern:[['14753.0', '15052.0', '30248.0']], support:2
# pattern:[['14753.0', '30248.0']], support:2
# pattern:[['14049.0']], support:3
# pattern:[['14049.0', '15039.0']], support:2
# pattern:[['14049.0', '30248.0']], support:2
# pattern:[['14418.0']], support:3
# pattern:[['14418.0', '30248.0']], support:2
# pattern:[['14031.0']], support:3
# pattern:[['14031.0', '30248.0']], support:3
# pattern:[['11148.0']], support:3
# pattern:[['10125.0']], support:3
# pattern:[['15644.0']], support:3
# pattern:[['15644.0', '30248.0']], support:2
# pattern:[['30235.0']], support:3
# pattern:[['14460.0']], support:3
# pattern:[['14460.0', '15590.0']], support:2
# pattern:[['14460.0', '15590.0', '30248.0']], support:2
# pattern:[['14460.0', '15092.0']], support:2
# pattern:[['14460.0', '15092.0', '30248.0']], support:2
# pattern:[['14460.0', '30248.0']], support:3
# pattern:[['15624.0']], support:3
# pattern:[['10719.0']], support:3
# pattern:[['10719.0', '10741.0']], support:2
# pattern:[['14727.0']], support:3
# pattern:[['10657.0']], support:3
# pattern:[['10657.0', '14338.0']], support:2
# pattern:[['10657.0', '14338.0', '30248.0']], support:2
# pattern:[['10657.0', '30248.0']], support:3
# pattern:[['11159.0']], support:3
# pattern:[['11159.0', '15631.0']], support:2
# pattern:[['15577.0']], support:3
# pattern:[['10632.0']], support:3
# pattern:[['10632.0', '30248.0']], support:2
# pattern:[['10741.0']], support:3
# pattern:[['10741.0', '15094.0']], support:2
# pattern:[['14435.0']], support:3
# pattern:[['14435.0', '30248.0']], support:2
# pattern:[['14435.0', '15012.0']], support:2
# pattern:[['14435.0', '15012.0', '30248.0']], support:2
# pattern:[['14435.0', '15052.0']], support:2
# pattern:[['14838.0']], support:4
# pattern:[['14838.0', '15039.0']], support:2
# pattern:[['14838.0', '15012.0']], support:2
# pattern:[['14838.0', '15012.0', '15039.0']], support:2
# pattern:[['11048.0']], support:4
# pattern:[['11048.0', '11159.0']], support:2
# pattern:[['11204.0']], support:4
# pattern:[['10198.0']], support:4
# pattern:[['14805.0']], support:4
# pattern:[['14805.0', '30248.0']], support:2
# pattern:[['14319.0']], support:4
# pattern:[['14319.0', '30248.0']], support:2
# pattern:[['14319.0', '15094.0']], support:2
# pattern:[['14319.0', '15052.0']], support:2
# pattern:[['14258.0']], support:4
# pattern:[['14258.0', '30248.0']], support:3
# pattern:[['11224.0']], support:4
# pattern:[['14357.0']], support:4
# pattern:[['14357.0', '14366.0']], support:2
# pattern:[['34214.0']], support:4
# pattern:[['14345.0']], support:4
# pattern:[['10199.0']], support:4
# pattern:[['15026.0']], support:4
# pattern:[['15026.0', '15590.0']], support:2
# pattern:[['15028.0']], support:4
# pattern:[['10710.0']], support:4
# pattern:[['10710.0', '30248.0']], support:3
# pattern:[['10710.0', '15052.0']], support:3
# pattern:[['10710.0', '15052.0', '30248.0']], support:2
# pattern:[['14224.0']], support:4
# pattern:[['14224.0', '14313.0']], support:2
# pattern:[['14224.0', '30248.0']], support:2
# pattern:[['14224.0', '15094.0']], support:2
# pattern:[['14208.0']], support:4
# pattern:[['14208.0', '30248.0']], support:2
# pattern:[['14208.0', '14350.0']], support:2
# pattern:[['15078.0']], support:4
# pattern:[['14126.0']], support:4
# pattern:[['14041.0']], support:4
# pattern:[['14041.0', '30248.0']], support:2
# pattern:[['11344.0']], support:4
# pattern:[['14341.0']], support:4
# pattern:[['14341.0', '15052.0']], support:2
# pattern:[['14318.0']], support:4
# pattern:[['14318.0', '30248.0']], support:2
# pattern:[['14035.0']], support:4
# pattern:[['14035.0', '15052.0']], support:2
# pattern:[['14005.0']], support:4
# pattern:[['14005.0', '15094.0']], support:2
# pattern:[['14005.0', '15052.0']], support:2
# pattern:[['15073.0']], support:4
# pattern:[['14268.0']], support:4
# pattern:[['14350.0']], support:4
# pattern:[['14350.0', '30248.0']], support:3
# pattern:[['30192.0']], support:4
# pattern:[['30192.0', '30248.0']], support:3
# pattern:[['14393.0']], support:4
# pattern:[['14393.0', '15012.0']], support:2
# pattern:[['14225.0']], support:4
# pattern:[['14225.0', '30248.0']], support:2
# pattern:[['10659.0']], support:4
# pattern:[['10659.0', '30248.0']], support:3
# pattern:[['10614.0']], support:4
# pattern:[['14803.0']], support:5
# pattern:[['14012.0']], support:5
# pattern:[['14354.0']], support:5
# pattern:[['14354.0', '30248.0']], support:2
# pattern:[['14354.0', '15052.0']], support:2
# pattern:[['11123.0']], support:5
# pattern:[['11123.0', '15039.0']], support:2
# pattern:[['11123.0', '15094.0']], support:2
# pattern:[['11123.0', '15094.0', '30248.0']], support:2
# pattern:[['11123.0', '15052.0']], support:2
# pattern:[['11123.0', '30248.0']], support:3
# pattern:[['34079.0']], support:5
# pattern:[['14069.0']], support:5
# pattern:[['14069.0', '15631.0']], support:2
# pattern:[['14069.0', '15631.0', '30248.0']], support:2
# pattern:[['14069.0', '15039.0']], support:4
# pattern:[['14069.0', '15039.0', '15631.0']], support:2
# pattern:[['14069.0', '15039.0', '15631.0', '30248.0']], support:2
# pattern:[['14069.0', '15039.0', '30248.0']], support:4
# pattern:[['14069.0', '30248.0']], support:4
# pattern:[['11114.0']], support:5
# pattern:[['11114.0', '11148.0']], support:2
# pattern:[['15067.0']], support:5
# pattern:[['15067.0', '15094.0']], support:2
# pattern:[['15067.0', '30248.0']], support:3
# pattern:[['14231.0']], support:5
# pattern:[['14678.0']], support:5
# pattern:[['10097.0']], support:6
# pattern:[['10097.0', '15094.0']], support:2
# pattern:[['10097.0', '10106.0']], support:2
# pattern:[['10097.0', '10106.0', '30248.0']], support:2
# pattern:[['10097.0', '10106.0', '15083.0']], support:2
# pattern:[['10097.0', '10106.0', '15083.0', '30248.0']], support:2
# pattern:[['10097.0', '14475.0']], support:2
# pattern:[['10097.0', '14475.0', '30248.0']], support:2
# pattern:[['10097.0', '14475.0', '15083.0']], support:2
# pattern:[['10097.0', '14475.0', '15083.0', '30248.0']], support:2
# pattern:[['10097.0', '30248.0']], support:3
# pattern:[['10097.0', '15083.0']], support:3
# pattern:[['10097.0', '15083.0', '30248.0']], support:3
# pattern:[['30833.0']], support:6
# pattern:[['10033.0']], support:6
# pattern:[['14627.0']], support:6
# pattern:[['14627.0', '15094.0']], support:2
# pattern:[['14627.0', '15012.0']], support:2
# pattern:[['14627.0', '15012.0', '30248.0']], support:2
# pattern:[['14627.0', '30248.0']], support:3
# pattern:[['11154.0']], support:6
# pattern:[['11154.0', '30248.0']], support:3
# pattern:[['14112.0']], support:6
# pattern:[['14112.0', '30248.0']], support:4
# pattern:[['10163.0']], support:6
# pattern:[['10163.0', '15631.0']], support:2
# pattern:[['14245.0']], support:6
# pattern:[['14245.0', '14622.0']], support:2
# pattern:[['14245.0', '30248.0']], support:2
# pattern:[['14245.0', '14281.0']], support:2
# pattern:[['14245.0', '15052.0']], support:2
# pattern:[['14705.0']], support:6
# pattern:[['14705.0', '15083.0']], support:2
# pattern:[['14705.0', '15083.0', '15094.0']], support:2
# pattern:[['14705.0', '15094.0']], support:2
# pattern:[['14705.0', '30248.0']], support:4
# pattern:[['14372.0']], support:6
# pattern:[['14372.0', '30248.0']], support:2
# pattern:[['14372.0', '14442.0']], support:2
# pattern:[['14372.0', '14442.0', '30248.0']], support:2
# pattern:[['14544.0']], support:6
# pattern:[['14544.0', '15052.0']], support:2
# pattern:[['11288.0']], support:7
# pattern:[['11385.0']], support:7
# pattern:[['11385.0', '15009.0']], support:2
# pattern:[['11385.0', '15009.0', '15052.0']], support:2
# pattern:[['11385.0', '15052.0']], support:3
# pattern:[['10104.0']], support:7
# pattern:[['10124.0']], support:7
# pattern:[['10124.0', '15039.0']], support:2
# pattern:[['10124.0', '15039.0', '30248.0']], support:2
# pattern:[['10124.0', '15052.0']], support:3
# pattern:[['10124.0', '15052.0', '30248.0']], support:2
# pattern:[['10124.0', '30248.0']], support:4
# pattern:[['32295.0']], support:7
# pattern:[['14443.0']], support:7
# pattern:[['14443.0', '15039.0']], support:2
# pattern:[['14079.0']], support:7
# pattern:[['14079.0', '30248.0']], support:2
# pattern:[['14079.0', '14810.0']], support:3
# pattern:[['14355.0']], support:7
# pattern:[['14355.0', '14622.0']], support:2
# pattern:[['14355.0', '14622.0', '15009.0']], support:2
# pattern:[['14355.0', '15009.0']], support:2
# pattern:[['14355.0', '14623.0']], support:2
# pattern:[['14355.0', '30253.0']], support:2
# pattern:[['14355.0', '30248.0']], support:2
# pattern:[['14355.0', '15039.0']], support:5
# pattern:[['14355.0', '14396.0']], support:6
# pattern:[['14355.0', '14396.0', '14622.0']], support:2
# pattern:[['14355.0', '14396.0', '14622.0', '15009.0']], support:2
# pattern:[['14355.0', '14396.0', '30248.0']], support:2
# pattern:[['14355.0', '14396.0', '15009.0']], support:2
# pattern:[['14355.0', '14396.0', '15039.0']], support:5
# pattern:[['10652.0']], support:7
# pattern:[['10652.0', '15012.0']], support:2
# pattern:[['10652.0', '30248.0']], support:3
# pattern:[['14333.0']], support:7
# pattern:[['14333.0', '14338.0']], support:2
# pattern:[['14333.0', '15052.0']], support:2
# pattern:[['15123.0']], support:7
# pattern:[['15123.0', '30248.0']], support:4
# pattern:[['10161.0']], support:7
# pattern:[['10161.0', '30248.0']], support:2
# pattern:[['15632.0']], support:7
# pattern:[['15057.0']], support:7
# pattern:[['15057.0', '30248.0']], support:2
# pattern:[['14213.0']], support:7
# pattern:[['14213.0', '30248.0']], support:2
# pattern:[['14213.0', '14810.0']], support:3
# pattern:[['10091.0']], support:8
# pattern:[['10091.0', '10211.0']], support:2
# pattern:[['10091.0', '10211.0', '10706.0']], support:2
# pattern:[['10091.0', '10211.0', '10706.0', '15052.0']], support:2
# pattern:[['10091.0', '10211.0', '15052.0']], support:2
# pattern:[['10091.0', '10706.0']], support:2
# pattern:[['10091.0', '10706.0', '15052.0']], support:2
# pattern:[['10091.0', '15052.0']], support:3
# pattern:[['14396.0']], support:8
# pattern:[['14396.0', '14622.0']], support:2
# pattern:[['14396.0', '14622.0', '15009.0']], support:2
# pattern:[['14396.0', '30248.0']], support:2
# pattern:[['14396.0', '15009.0']], support:2
# pattern:[['14396.0', '15052.0']], support:3
# pattern:[['14396.0', '15039.0']], support:5
# pattern:[['10094.0']], support:8
# pattern:[['10094.0', '30248.0']], support:5
# pattern:[['14545.0']], support:8
# pattern:[['14545.0', '30248.0']], support:3
# pattern:[['14545.0', '15012.0']], support:3
# pattern:[['11079.0']], support:8
# pattern:[['11079.0', '30248.0']], support:3
# pattern:[['14043.0']], support:8
# pattern:[['14043.0', '15094.0']], support:2
# pattern:[['14043.0', '15039.0']], support:2
# pattern:[['14043.0', '30248.0']], support:3
# pattern:[['14152.0']], support:8
# pattern:[['14152.0', '30248.0']], support:3
# pattern:[['14152.0', '15094.0']], support:3
# pattern:[['14168.0']], support:8
# pattern:[['14168.0', '14177.0']], support:2
# pattern:[['14168.0', '30248.0']], support:2
# pattern:[['14168.0', '15094.0']], support:2
# pattern:[['14168.0', '14173.0']], support:2
# pattern:[['14168.0', '14173.0', '30248.0']], support:2
# pattern:[['14168.0', '15052.0']], support:2
# pattern:[['14330.0']], support:8
# pattern:[['14330.0', '15094.0']], support:2
# pattern:[['14191.0']], support:8
# pattern:[['14191.0', '15052.0']], support:2
# pattern:[['14475.0']], support:9
# pattern:[['14475.0', '15083.0']], support:2
# pattern:[['14475.0', '15083.0', '30248.0']], support:2
# pattern:[['14475.0', '30248.0']], support:5
# pattern:[['10142.0']], support:9
# pattern:[['14573.0']], support:9
# pattern:[['14573.0', '30248.0']], support:2
# pattern:[['14573.0', '15052.0']], support:3
# pattern:[['10068.0']], support:9
# pattern:[['10068.0', '10211.0']], support:2
# pattern:[['10068.0', '10703.0']], support:2
# pattern:[['10068.0', '15052.0']], support:2
# pattern:[['10068.0', '10086.0']], support:2
# pattern:[['10068.0', '30248.0']], support:4
# pattern:[['10083.0']], support:9
# pattern:[['14082.0']], support:10
# pattern:[['14082.0', '15094.0']], support:2
# pattern:[['14082.0', '14196.0']], support:2
# pattern:[['14082.0', '14362.0']], support:2
# pattern:[['14082.0', '15092.0']], support:2
# pattern:[['14082.0', '15092.0', '30248.0']], support:2
# pattern:[['14082.0', '30248.0']], support:4
# pattern:[['14313.0']], support:10
# pattern:[['14313.0', '15039.0']], support:2
# pattern:[['14313.0', '30248.0']], support:3
# pattern:[['14313.0', '15094.0']], support:3
# pattern:[['10064.0']], support:10
# pattern:[['10064.0', '30248.0']], support:2
# pattern:[['10064.0', '15094.0']], support:2
# pattern:[['10062.0']], support:10
# pattern:[['10062.0', '10657.0']], support:2
# pattern:[['10062.0', '10657.0', '30248.0']], support:2
# pattern:[['10062.0', '30248.0']], support:3
# pattern:[['15045.0']], support:10
# pattern:[['15045.0', '30248.0']], support:2
# pattern:[['15045.0', '15094.0']], support:2
# pattern:[['15045.0', '15631.0']], support:2
# pattern:[['14652.0']], support:10
# pattern:[['14652.0', '15028.0']], support:3
# pattern:[['14652.0', '30248.0']], support:4
# pattern:[['14044.0']], support:11
# pattern:[['14044.0', '15631.0']], support:2
# pattern:[['14044.0', '15052.0']], support:2
# pattern:[['14044.0', '15039.0']], support:2
# pattern:[['14044.0', '15012.0']], support:3
# pattern:[['14044.0', '15012.0', '15631.0']], support:2
# pattern:[['14044.0', '14265.0']], support:3
# pattern:[['14044.0', '14265.0', '15009.0']], support:2
# pattern:[['14044.0', '15009.0']], support:6
# pattern:[['10211.0']], support:11
# pattern:[['10211.0', '10706.0']], support:2
# pattern:[['10211.0', '10706.0', '15052.0']], support:2
# pattern:[['10211.0', '15039.0']], support:2
# pattern:[['10211.0', '15039.0', '30248.0']], support:2
# pattern:[['10211.0', '15094.0']], support:2
# pattern:[['10211.0', '15052.0']], support:2
# pattern:[['10211.0', '30248.0']], support:6
# pattern:[['10080.0']], support:11
# pattern:[['10080.0', '14177.0']], support:2
# pattern:[['10080.0', '14177.0', '15012.0']], support:2
# pattern:[['10080.0', '15631.0']], support:2
# pattern:[['10080.0', '14044.0']], support:2
# pattern:[['10080.0', '14044.0', '15012.0']], support:2
# pattern:[['10080.0', '30248.0']], support:3
# pattern:[['10080.0', '15012.0']], support:3
# pattern:[['10080.0', '15012.0', '15631.0']], support:2
# pattern:[['14338.0']], support:11
# pattern:[['14338.0', '14705.0']], support:2
# pattern:[['14338.0', '14705.0', '30248.0']], support:2
# pattern:[['14338.0', '30248.0']], support:6
# pattern:[['14442.0']], support:11
# pattern:[['14442.0', '14445.0']], support:2
# pattern:[['14442.0', '30248.0']], support:5
# pattern:[['14098.0']], support:12
# pattern:[['14098.0', '14652.0']], support:2
# pattern:[['14098.0', '14333.0']], support:2
# pattern:[['14098.0', '15039.0']], support:2
# pattern:[['14098.0', '14366.0']], support:2
# pattern:[['14098.0', '30248.0']], support:3
# pattern:[['14098.0', '15052.0']], support:3
# pattern:[['11129.0']], support:12
# pattern:[['11129.0', '30248.0']], support:5
# pattern:[['15083.0']], support:12
# pattern:[['15083.0', '15094.0']], support:3
# pattern:[['15083.0', '30248.0']], support:4
# pattern:[['14281.0']], support:12
# pattern:[['14281.0', '15039.0']], support:2
# pattern:[['14281.0', '14442.0']], support:3
# pattern:[['14281.0', '30248.0']], support:6
# pattern:[['14322.0']], support:12
# pattern:[['14322.0', '15052.0']], support:2
# pattern:[['14322.0', '30248.0']], support:3
# pattern:[['14322.0', '15094.0']], support:3
# pattern:[['14322.0', '15631.0']], support:3
# pattern:[['14071.0']], support:12
# pattern:[['14071.0', '14622.0']], support:2
# pattern:[['14071.0', '14622.0', '30248.0']], support:2
# pattern:[['14071.0', '15012.0']], support:2
# pattern:[['14071.0', '14281.0']], support:2
# pattern:[['14071.0', '15039.0']], support:2
# pattern:[['14071.0', '14245.0']], support:2
# pattern:[['14071.0', '14245.0', '14281.0']], support:2
# pattern:[['14071.0', '14322.0']], support:2
# pattern:[['14071.0', '14196.0']], support:3
# pattern:[['14071.0', '14196.0', '30248.0']], support:3
# pattern:[['14071.0', '30248.0']], support:6
# pattern:[['10107.0']], support:12
# pattern:[['10107.0', '14281.0']], support:2
# pattern:[['10107.0', '30248.0']], support:3
# pattern:[['14173.0']], support:12
# pattern:[['14173.0', '14622.0']], support:2
# pattern:[['14173.0', '14177.0']], support:2
# pattern:[['14173.0', '14196.0']], support:2
# pattern:[['14173.0', '14245.0']], support:2
# pattern:[['14173.0', '14245.0', '14622.0']], support:2
# pattern:[['14173.0', '30248.0']], support:4
# pattern:[['14366.0']], support:13
# pattern:[['14366.0', '15039.0']], support:2
# pattern:[['14366.0', '15052.0']], support:2
# pattern:[['14366.0', '14810.0']], support:2
# pattern:[['14366.0', '14810.0', '30248.0']], support:2
# pattern:[['14366.0', '30248.0']], support:4
# pattern:[['10706.0']], support:13
# pattern:[['10706.0', '34214.0']], support:2
# pattern:[['10706.0', '15039.0']], support:2
# pattern:[['10706.0', '15094.0']], support:2
# pattern:[['10706.0', '15052.0']], support:3
# pattern:[['10706.0', '30248.0']], support:5
# pattern:[['10706.0', '30248.0', '34214.0']], support:2
# pattern:[['15011.0']], support:14
# pattern:[['15011.0', '15039.0']], support:2
# pattern:[['15011.0', '15052.0']], support:2
# pattern:[['15011.0', '15052.0', '15094.0']], support:2
# pattern:[['15011.0', '15012.0']], support:3
# pattern:[['15011.0', '15012.0', '15094.0']], support:2
# pattern:[['15011.0', '15012.0', '15094.0', '30248.0']], support:2
# pattern:[['15011.0', '15012.0', '30248.0']], support:2
# pattern:[['15011.0', '30248.0']], support:5
# pattern:[['15011.0', '15094.0']], support:5
# pattern:[['15011.0', '15094.0', '30248.0']], support:3
# pattern:[['15066.0']], support:15
# pattern:[['15066.0', '15631.0']], support:3
# pattern:[['15066.0', '30248.0']], support:4
# pattern:[['14051.0']], support:16
# pattern:[['14051.0', '14350.0']], support:2
# pattern:[['14051.0', '14082.0']], support:2
# pattern:[['14051.0', '14196.0']], support:2
# pattern:[['14051.0', '15009.0']], support:2
# pattern:[['14051.0', '30248.0']], support:2
# pattern:[['14051.0', '14208.0']], support:2
# pattern:[['14051.0', '14208.0', '14350.0']], support:2
# pattern:[['14051.0', '15052.0']], support:2
# pattern:[['14051.0', '14322.0']], support:3
# pattern:[['10007.0']], support:17
# pattern:[['10007.0', '10080.0']], support:2
# pattern:[['10007.0', '10706.0']], support:2
# pattern:[['10007.0', '14191.0']], support:2
# pattern:[['10007.0', '10060.0']], support:3
# pattern:[['10007.0', '30248.0']], support:7
# pattern:[['15060.0']], support:17
# pattern:[['15060.0', '15094.0']], support:2
# pattern:[['15060.0', '30248.0']], support:7
# pattern:[['15590.0']], support:17
# pattern:[['15590.0', '30248.0']], support:7
# pattern:[['10106.0']], support:17
# pattern:[['10106.0', '15083.0']], support:2
# pattern:[['10106.0', '15083.0', '30248.0']], support:2
# pattern:[['10106.0', '15039.0']], support:2
# pattern:[['10106.0', '15094.0']], support:2
# pattern:[['10106.0', '10710.0']], support:3
# pattern:[['10106.0', '10710.0', '15052.0']], support:2
# pattern:[['10106.0', '10710.0', '15052.0', '30248.0']], support:2
# pattern:[['10106.0', '10710.0', '30248.0']], support:3
# pattern:[['10106.0', '15038.0']], support:3
# pattern:[['10106.0', '15052.0']], support:3
# pattern:[['10106.0', '15052.0', '30248.0']], support:2
# pattern:[['10106.0', '30248.0']], support:4
# pattern:[['14362.0']], support:17
# pattern:[['14362.0', '14803.0']], support:2
# pattern:[['14362.0', '15066.0']], support:2
# pattern:[['14362.0', '14627.0']], support:2
# pattern:[['14362.0', '14627.0', '30248.0']], support:2
# pattern:[['14362.0', '14627.0', '15012.0']], support:2
# pattern:[['14362.0', '14627.0', '15012.0', '30248.0']], support:2
# pattern:[['14362.0', '15060.0']], support:2
# pattern:[['14362.0', '15092.0']], support:2
# pattern:[['14362.0', '15092.0', '30248.0']], support:2
# pattern:[['14362.0', '15012.0']], support:4
# pattern:[['14362.0', '15012.0', '30248.0']], support:4
# pattern:[['14362.0', '15631.0']], support:4
# pattern:[['14362.0', '30248.0']], support:6
# pattern:[['14265.0']], support:17
# pattern:[['14265.0', '15066.0']], support:2
# pattern:[['14265.0', '30248.0']], support:2
# pattern:[['14265.0', '15052.0']], support:2
# pattern:[['14265.0', '15009.0']], support:3
# pattern:[['14265.0', '15038.0']], support:3
# pattern:[['14265.0', '15038.0', '15066.0']], support:2
# pattern:[['14622.0']], support:18
# pattern:[['14622.0', '15094.0']], support:2
# pattern:[['14622.0', '15039.0']], support:2
# pattern:[['14622.0', '15012.0']], support:2
# pattern:[['14622.0', '15012.0', '15092.0']], support:2
# pattern:[['14622.0', '15092.0']], support:2
# pattern:[['14622.0', '15009.0']], support:3
# pattern:[['14622.0', '15009.0', '30248.0']], support:2
# pattern:[['14622.0', '15052.0']], support:5
# pattern:[['14622.0', '15052.0', '30248.0']], support:3
# pattern:[['14622.0', '30248.0']], support:8
# pattern:[['14810.0']], support:20
# pattern:[['14810.0', '15631.0']], support:2
# pattern:[['14810.0', '15012.0']], support:2
# pattern:[['14810.0', '15052.0']], support:3
# pattern:[['14810.0', '30248.0']], support:4
# pattern:[['14177.0']], support:21
# pattern:[['14177.0', '15083.0']], support:2
# pattern:[['14177.0', '14442.0']], support:2
# pattern:[['14177.0', '15094.0']], support:2
# pattern:[['14177.0', '15052.0']], support:2
# pattern:[['14177.0', '15052.0', '15094.0']], support:2
# pattern:[['14177.0', '15012.0']], support:3
# pattern:[['14177.0', '30248.0']], support:3
# pattern:[['14196.0']], support:21
# pattern:[['14196.0', '14622.0']], support:2
# pattern:[['14196.0', '14622.0', '15052.0']], support:2
# pattern:[['14196.0', '15012.0']], support:2
# pattern:[['14196.0', '15012.0', '30248.0']], support:2
# pattern:[['14196.0', '14442.0']], support:2
# pattern:[['14196.0', '14627.0']], support:2
# pattern:[['14196.0', '14678.0']], support:2
# pattern:[['14196.0', '14362.0']], support:2
# pattern:[['14196.0', '14245.0']], support:2
# pattern:[['14196.0', '14208.0']], support:2
# pattern:[['14196.0', '14281.0']], support:3
# pattern:[['14196.0', '14281.0', '30248.0']], support:2
# pattern:[['14196.0', '15052.0']], support:3
# pattern:[['14196.0', '15052.0', '30248.0']], support:2
# pattern:[['14196.0', '14322.0']], support:3
# pattern:[['14196.0', '30248.0']], support:11
# pattern:[['15038.0']], support:21
# pattern:[['15038.0', '15094.0']], support:2
# pattern:[['15038.0', '15094.0', '30248.0']], support:2
# pattern:[['15038.0', '15073.0']], support:2
# pattern:[['15038.0', '15045.0']], support:3
# pattern:[['15038.0', '15045.0', '15631.0']], support:2
# pattern:[['15038.0', '15066.0']], support:3
# pattern:[['15038.0', '15631.0']], support:4
# pattern:[['15038.0', '15052.0']], support:4
# pattern:[['15038.0', '30248.0']], support:7
# pattern:[['30170.0']], support:22
# pattern:[['30170.0', '32295.0']], support:2
# pattern:[['30170.0', '30248.0']], support:5
# pattern:[['30170.0', '30248.0', '32295.0']], support:2
# pattern:[['14160.0']], support:25
# pattern:[['14160.0', '14357.0']], support:2
# pattern:[['14160.0', '14678.0']], support:2
# pattern:[['14160.0', '15045.0']], support:2
# pattern:[['14160.0', '15631.0']], support:2
# pattern:[['14160.0', '15092.0']], support:2
# pattern:[['14160.0', '30248.0']], support:4
# pattern:[['14160.0', '15052.0']], support:4
# pattern:[['14160.0', '15094.0']], support:5
# pattern:[['14160.0', '15094.0', '30248.0']], support:2
# pattern:[['15092.0']], support:34
# pattern:[['15092.0', '15094.0']], support:8
# pattern:[['15092.0', '30248.0']], support:11
# pattern:[['10060.0']], support:49
# pattern:[['10060.0', '10094.0']], support:2
# pattern:[['10060.0', '10068.0']], support:2
# pattern:[['10060.0', '15039.0']], support:2
# pattern:[['10060.0', '15092.0']], support:2
# pattern:[['10060.0', '10161.0']], support:3
# pattern:[['10060.0', '15009.0']], support:3
# pattern:[['10060.0', '15009.0', '15092.0']], support:2
# pattern:[['10060.0', '10086.0']], support:5
# pattern:[['10060.0', '15631.0']], support:5
# pattern:[['10060.0', '15631.0', '30248.0']], support:2
# pattern:[['10060.0', '10064.0']], support:6
# pattern:[['10060.0', '30248.0']], support:11
# pattern:[['15009.0']], support:53
# pattern:[['15009.0', '15045.0']], support:2
# pattern:[['15009.0', '15038.0']], support:2
# pattern:[['15009.0', '15060.0']], support:2
# pattern:[['15009.0', '15066.0']], support:3
# pattern:[['15009.0', '15066.0', '30248.0']], support:2
# pattern:[['15009.0', '15039.0']], support:3
# pattern:[['15009.0', '15012.0']], support:3
# pattern:[['15009.0', '15052.0']], support:5
# pattern:[['15009.0', '15092.0']], support:7
# pattern:[['15009.0', '15092.0', '30248.0']], support:2
# pattern:[['15009.0', '15094.0']], support:8
# pattern:[['15009.0', '15094.0', '15631.0']], support:2
# pattern:[['15009.0', '15631.0']], support:8
# pattern:[['15009.0', '15631.0', '30248.0']], support:3
# pattern:[['15009.0', '30248.0']], support:11
# pattern:[['10086.0']], support:55
# pattern:[['10086.0', '10154.0']], support:2
# pattern:[['10086.0', '14350.0']], support:2
# pattern:[['10086.0', '14350.0', '30248.0']], support:2
# pattern:[['10086.0', '14071.0']], support:2
# pattern:[['10086.0', '31017.0']], support:2
# pattern:[['10086.0', '10094.0']], support:2
# pattern:[['10086.0', '10094.0', '30248.0']], support:2
# pattern:[['10086.0', '11123.0']], support:2
# pattern:[['10086.0', '11123.0', '15052.0']], support:2
# pattern:[['10086.0', '15009.0']], support:2
# pattern:[['10086.0', '34214.0']], support:2
# pattern:[['10086.0', '10719.0']], support:2
# pattern:[['10086.0', '10719.0', '10741.0']], support:2
# pattern:[['10086.0', '10741.0']], support:2
# pattern:[['10086.0', '10107.0']], support:3
# pattern:[['10086.0', '10107.0', '30248.0']], support:2
# pattern:[['10086.0', '10706.0']], support:3
# pattern:[['10086.0', '10706.0', '34214.0']], support:2
# pattern:[['10086.0', '10706.0', '30248.0']], support:3
# pattern:[['10086.0', '10706.0', '30248.0', '34214.0']], support:2
# pattern:[['10086.0', '10106.0']], support:3
# pattern:[['10086.0', '10106.0', '15052.0']], support:2
# pattern:[['10086.0', '15012.0']], support:4
# pattern:[['10086.0', '15012.0', '30248.0']], support:3
# pattern:[['10086.0', '15052.0']], support:4
# pattern:[['10086.0', '15052.0', '30248.0']], support:2
# pattern:[['10086.0', '15039.0']], support:5
# pattern:[['10086.0', '15039.0', '30248.0']], support:3
# pattern:[['10086.0', '15631.0']], support:5
# pattern:[['10086.0', '15094.0']], support:6
# pattern:[['10086.0', '15094.0', '15631.0']], support:3
# pattern:[['10086.0', '15094.0', '30248.0']], support:3
# pattern:[['10086.0', '30248.0']], support:19
# pattern:[['10086.0', '30248.0', '34214.0']], support:2
# pattern:[['15631.0']], support:89
# pattern:[['15631.0', '30170.0']], support:3
# pattern:[['15631.0', '30248.0']], support:26
# pattern:[['15039.0']], support:91
# pattern:[['15039.0', '34003.0']], support:2
# pattern:[['15039.0', '15590.0']], support:3
# pattern:[['15039.0', '15590.0', '30248.0']], support:3
# pattern:[['15039.0', '15092.0']], support:5
# pattern:[['15039.0', '15092.0', '15094.0']], support:2
# pattern:[['15039.0', '15631.0']], support:6
# pattern:[['15039.0', '15631.0', '30248.0']], support:5
# pattern:[['15039.0', '15052.0']], support:12
# pattern:[['15039.0', '15052.0', '30248.0']], support:5
# pattern:[['15039.0', '15094.0']], support:13
# pattern:[['15039.0', '15094.0', '30248.0']], support:5
# pattern:[['15039.0', '30248.0']], support:29
# pattern:[['15012.0']], support:107
# pattern:[['15012.0', '15057.0']], support:2
# pattern:[['15012.0', '15083.0']], support:2
# pattern:[['15012.0', '30192.0']], support:2
# pattern:[['15012.0', '15632.0']], support:2
# pattern:[['15012.0', '15060.0']], support:3
# pattern:[['15012.0', '15060.0', '30248.0']], support:3
# pattern:[['15012.0', '15092.0']], support:7
# pattern:[['15012.0', '15092.0', '30248.0']], support:3
# pattern:[['15012.0', '15052.0']], support:8
# pattern:[['15012.0', '15052.0', '15094.0']], support:3
# pattern:[['15012.0', '15052.0', '15092.0']], support:3
# pattern:[['15012.0', '15052.0', '15092.0', '30248.0']], support:2
# pattern:[['15012.0', '15052.0', '30248.0']], support:4
# pattern:[['15012.0', '15631.0']], support:9
# pattern:[['15012.0', '15631.0', '30248.0']], support:3
# pattern:[['15012.0', '15039.0']], support:12
# pattern:[['15012.0', '15039.0', '15631.0']], support:2
# pattern:[['15012.0', '15039.0', '15094.0']], support:2
# pattern:[['15012.0', '15039.0', '30248.0']], support:4
# pattern:[['15012.0', '15094.0']], support:14
# pattern:[['15012.0', '15094.0', '30248.0']], support:5
# pattern:[['15012.0', '30248.0']], support:28
# pattern:[['15052.0']], support:116
# pattern:[['15052.0', '15067.0']], support:2
# pattern:[['15052.0', '15060.0']], support:2
# pattern:[['15052.0', '31017.0']], support:2
# pattern:[['15052.0', '15123.0']], support:3
# pattern:[['15052.0', '15123.0', '30248.0']], support:3
# pattern:[['15052.0', '15092.0']], support:5
# pattern:[['15052.0', '15092.0', '30248.0']], support:2
# pattern:[['15052.0', '15631.0']], support:7
# pattern:[['15052.0', '15631.0', '30248.0']], support:2
# pattern:[['15052.0', '15094.0']], support:24
# pattern:[['15052.0', '15094.0', '15631.0']], support:3
# pattern:[['15052.0', '15094.0', '30248.0']], support:9
# pattern:[['15052.0', '30248.0']], support:28
# pattern:[['15094.0']], support:122
# pattern:[['15094.0', '15123.0']], support:2
# pattern:[['15094.0', '15631.0']], support:10
# pattern:[['15094.0', '15631.0', '30248.0']], support:3
# pattern:[['15094.0', '30248.0']], support:34
# pattern:[['30248.0']], support:251
# pattern:[['30248.0', '34214.0']], support:2
# pattern:[['30248.0', '30833.0']], support:2
# pattern:[['30248.0', '34079.0']], support:2
# pattern:[['30248.0', '32295.0']], support:3
# pattern:[['30248.0', '32133.0']], support:3
#
# min_support = 4:
# pattern:[['14838.0']], support:4
# pattern:[['11048.0']], support:4
# pattern:[['11204.0']], support:4
# pattern:[['10198.0']], support:4
# pattern:[['14805.0']], support:4
# pattern:[['14319.0']], support:4
# pattern:[['14258.0']], support:4
# pattern:[['11224.0']], support:4
# pattern:[['14357.0']], support:4
# pattern:[['34214.0']], support:4
# pattern:[['14345.0']], support:4
# pattern:[['10199.0']], support:4
# pattern:[['15026.0']], support:4
# pattern:[['15028.0']], support:4
# pattern:[['10710.0']], support:4
# pattern:[['14224.0']], support:4
# pattern:[['14208.0']], support:4
# pattern:[['15078.0']], support:4
# pattern:[['14126.0']], support:4
# pattern:[['14041.0']], support:4
# pattern:[['11344.0']], support:4
# pattern:[['14341.0']], support:4
# pattern:[['14318.0']], support:4
# pattern:[['14035.0']], support:4
# pattern:[['14005.0']], support:4
# pattern:[['15073.0']], support:4
# pattern:[['14268.0']], support:4
# pattern:[['14350.0']], support:4
# pattern:[['30192.0']], support:4
# pattern:[['14393.0']], support:4
# pattern:[['14225.0']], support:4
# pattern:[['10659.0']], support:4
# pattern:[['10614.0']], support:4
# pattern:[['14803.0']], support:5
# pattern:[['14012.0']], support:5
# pattern:[['14354.0']], support:5
# pattern:[['11123.0']], support:5
# pattern:[['34079.0']], support:5
# pattern:[['14069.0']], support:5
# pattern:[['14069.0', '15039.0']], support:4
# pattern:[['14069.0', '15039.0', '30248.0']], support:4
# pattern:[['14069.0', '30248.0']], support:4
# pattern:[['11114.0']], support:5
# pattern:[['15067.0']], support:5
# pattern:[['14231.0']], support:5
# pattern:[['14678.0']], support:5
# pattern:[['10097.0']], support:6
# pattern:[['30833.0']], support:6
# pattern:[['10033.0']], support:6
# pattern:[['14627.0']], support:6
# pattern:[['11154.0']], support:6
# pattern:[['14112.0']], support:6
# pattern:[['14112.0', '30248.0']], support:4
# pattern:[['10163.0']], support:6
# pattern:[['14245.0']], support:6
# pattern:[['14705.0']], support:6
# pattern:[['14705.0', '30248.0']], support:4
# pattern:[['14372.0']], support:6
# pattern:[['14544.0']], support:6
# pattern:[['11288.0']], support:7
# pattern:[['11385.0']], support:7
# pattern:[['10104.0']], support:7
# pattern:[['10124.0']], support:7
# pattern:[['10124.0', '30248.0']], support:4
# pattern:[['32295.0']], support:7
# pattern:[['14443.0']], support:7
# pattern:[['14079.0']], support:7
# pattern:[['14355.0']], support:7
# pattern:[['14355.0', '15039.0']], support:5
# pattern:[['14355.0', '14396.0']], support:6
# pattern:[['14355.0', '14396.0', '15039.0']], support:5
# pattern:[['10652.0']], support:7
# pattern:[['14333.0']], support:7
# pattern:[['15123.0']], support:7
# pattern:[['15123.0', '30248.0']], support:4
# pattern:[['10161.0']], support:7
# pattern:[['15632.0']], support:7
# pattern:[['15057.0']], support:7
# pattern:[['14213.0']], support:7
# pattern:[['10091.0']], support:8
# pattern:[['14396.0']], support:8
# pattern:[['14396.0', '15039.0']], support:5
# pattern:[['10094.0']], support:8
# pattern:[['10094.0', '30248.0']], support:5
# pattern:[['14545.0']], support:8
# pattern:[['11079.0']], support:8
# pattern:[['14043.0']], support:8
# pattern:[['14152.0']], support:8
# pattern:[['14168.0']], support:8
# pattern:[['14330.0']], support:8
# pattern:[['14191.0']], support:8
# pattern:[['14475.0']], support:9
# pattern:[['14475.0', '30248.0']], support:5
# pattern:[['10142.0']], support:9
# pattern:[['14573.0']], support:9
# pattern:[['10068.0']], support:9
# pattern:[['10068.0', '30248.0']], support:4
# pattern:[['10083.0']], support:9
# pattern:[['14082.0']], support:10
# pattern:[['14082.0', '30248.0']], support:4
# pattern:[['14313.0']], support:10
# pattern:[['10064.0']], support:10
# pattern:[['10062.0']], support:10
# pattern:[['15045.0']], support:10
# pattern:[['14652.0']], support:10
# pattern:[['14652.0', '30248.0']], support:4
# pattern:[['14044.0']], support:11
# pattern:[['14044.0', '15009.0']], support:6
# pattern:[['10211.0']], support:11
# pattern:[['10211.0', '30248.0']], support:6
# pattern:[['10080.0']], support:11
# pattern:[['14338.0']], support:11
# pattern:[['14338.0', '30248.0']], support:6
# pattern:[['14442.0']], support:11
# pattern:[['14442.0', '30248.0']], support:5
# pattern:[['14098.0']], support:12
# pattern:[['11129.0']], support:12
# pattern:[['11129.0', '30248.0']], support:5
# pattern:[['15083.0']], support:12
# pattern:[['15083.0', '30248.0']], support:4
# pattern:[['14281.0']], support:12
# pattern:[['14281.0', '30248.0']], support:6
# pattern:[['14322.0']], support:12
# pattern:[['14071.0']], support:12
# pattern:[['14071.0', '30248.0']], support:6
# pattern:[['10107.0']], support:12
# pattern:[['14173.0']], support:12
# pattern:[['14173.0', '30248.0']], support:4
# pattern:[['14366.0']], support:13
# pattern:[['14366.0', '30248.0']], support:4
# pattern:[['10706.0']], support:13
# pattern:[['10706.0', '30248.0']], support:5
# pattern:[['15011.0']], support:14
# pattern:[['15011.0', '30248.0']], support:5
# pattern:[['15011.0', '15094.0']], support:5
# pattern:[['15066.0']], support:15
# pattern:[['15066.0', '30248.0']], support:4
# pattern:[['14051.0']], support:16
# pattern:[['10007.0']], support:17
# pattern:[['10007.0', '30248.0']], support:7
# pattern:[['15060.0']], support:17
# pattern:[['15060.0', '30248.0']], support:7
# pattern:[['15590.0']], support:17
# pattern:[['15590.0', '30248.0']], support:7
# pattern:[['10106.0']], support:17
# pattern:[['10106.0', '30248.0']], support:4
# pattern:[['14362.0']], support:17
# pattern:[['14362.0', '15012.0']], support:4
# pattern:[['14362.0', '15012.0', '30248.0']], support:4
# pattern:[['14362.0', '15631.0']], support:4
# pattern:[['14362.0', '30248.0']], support:6
# pattern:[['14265.0']], support:17
# pattern:[['14622.0']], support:18
# pattern:[['14622.0', '15052.0']], support:5
# pattern:[['14622.0', '30248.0']], support:8
# pattern:[['14810.0']], support:20
# pattern:[['14810.0', '30248.0']], support:4
# pattern:[['14177.0']], support:21
# pattern:[['14196.0']], support:21
# pattern:[['14196.0', '30248.0']], support:11
# pattern:[['15038.0']], support:21
# pattern:[['15038.0', '15631.0']], support:4
# pattern:[['15038.0', '15052.0']], support:4
# pattern:[['15038.0', '30248.0']], support:7
# pattern:[['30170.0']], support:22
# pattern:[['30170.0', '30248.0']], support:5
# pattern:[['14160.0']], support:25
# pattern:[['14160.0', '30248.0']], support:4
# pattern:[['14160.0', '15052.0']], support:4
# pattern:[['14160.0', '15094.0']], support:5
# pattern:[['15092.0']], support:34
# pattern:[['15092.0', '15094.0']], support:8
# pattern:[['15092.0', '30248.0']], support:11
# pattern:[['10060.0']], support:49
# pattern:[['10060.0', '10086.0']], support:5
# pattern:[['10060.0', '15631.0']], support:5
# pattern:[['10060.0', '10064.0']], support:6
# pattern:[['10060.0', '30248.0']], support:11
# pattern:[['15009.0']], support:53
# pattern:[['15009.0', '15052.0']], support:5
# pattern:[['15009.0', '15092.0']], support:7
# pattern:[['15009.0', '15094.0']], support:8
# pattern:[['15009.0', '15631.0']], support:8
# pattern:[['15009.0', '30248.0']], support:11
# pattern:[['10086.0']], support:55
# pattern:[['10086.0', '15012.0']], support:4
# pattern:[['10086.0', '15052.0']], support:4
# pattern:[['10086.0', '15039.0']], support:5
# pattern:[['10086.0', '15631.0']], support:5
# pattern:[['10086.0', '15094.0']], support:6
# pattern:[['10086.0', '30248.0']], support:19
# pattern:[['15631.0']], support:89
# pattern:[['15631.0', '30248.0']], support:26
# pattern:[['15039.0']], support:91
# pattern:[['15039.0', '15092.0']], support:5
# pattern:[['15039.0', '15631.0']], support:6
# pattern:[['15039.0', '15631.0', '30248.0']], support:5
# pattern:[['15039.0', '15052.0']], support:12
# pattern:[['15039.0', '15052.0', '30248.0']], support:5
# pattern:[['15039.0', '15094.0']], support:13
# pattern:[['15039.0', '15094.0', '30248.0']], support:5
# pattern:[['15039.0', '30248.0']], support:29
# pattern:[['15012.0']], support:107
# pattern:[['15012.0', '15092.0']], support:7
# pattern:[['15012.0', '15052.0']], support:8
# pattern:[['15012.0', '15052.0', '30248.0']], support:4
# pattern:[['15012.0', '15631.0']], support:9
# pattern:[['15012.0', '15039.0']], support:12
# pattern:[['15012.0', '15039.0', '30248.0']], support:4
# pattern:[['15012.0', '15094.0']], support:14
# pattern:[['15012.0', '15094.0', '30248.0']], support:5
# pattern:[['15012.0', '30248.0']], support:28
# pattern:[['15052.0']], support:116
# pattern:[['15052.0', '15092.0']], support:5
# pattern:[['15052.0', '15631.0']], support:7
# pattern:[['15052.0', '15094.0']], support:24
# pattern:[['15052.0', '15094.0', '30248.0']], support:9
# pattern:[['15052.0', '30248.0']], support:28
# pattern:[['15094.0']], support:122
# pattern:[['15094.0', '15631.0']], support:10
# pattern:[['15094.0', '30248.0']], support:34
# pattern:[['30248.0']], support:251
#
# min_support = 8:
# pattern:[['10091.0']], support:8
# pattern:[['14396.0']], support:8
# pattern:[['10094.0']], support:8
# pattern:[['14545.0']], support:8
# pattern:[['11079.0']], support:8
# pattern:[['14043.0']], support:8
# pattern:[['14152.0']], support:8
# pattern:[['14168.0']], support:8
# pattern:[['14330.0']], support:8
# pattern:[['14191.0']], support:8
# pattern:[['14475.0']], support:9
# pattern:[['10142.0']], support:9
# pattern:[['14573.0']], support:9
# pattern:[['10068.0']], support:9
# pattern:[['10083.0']], support:9
# pattern:[['14082.0']], support:10
# pattern:[['14313.0']], support:10
# pattern:[['10064.0']], support:10
# pattern:[['10062.0']], support:10
# pattern:[['15045.0']], support:10
# pattern:[['14652.0']], support:10
# pattern:[['14044.0']], support:11
# pattern:[['10211.0']], support:11
# pattern:[['10080.0']], support:11
# pattern:[['14338.0']], support:11
# pattern:[['14442.0']], support:11
# pattern:[['14098.0']], support:12
# pattern:[['11129.0']], support:12
# pattern:[['15083.0']], support:12
# pattern:[['14281.0']], support:12
# pattern:[['14322.0']], support:12
# pattern:[['14071.0']], support:12
# pattern:[['10107.0']], support:12
# pattern:[['14173.0']], support:12
# pattern:[['14366.0']], support:13
# pattern:[['10706.0']], support:13
# pattern:[['15011.0']], support:14
# pattern:[['15066.0']], support:15
# pattern:[['14051.0']], support:16
# pattern:[['10007.0']], support:17
# pattern:[['15060.0']], support:17
# pattern:[['15590.0']], support:17
# pattern:[['10106.0']], support:17
# pattern:[['14362.0']], support:17
# pattern:[['14265.0']], support:17
# pattern:[['14622.0']], support:18
# pattern:[['14622.0', '30248.0']], support:8
# pattern:[['14810.0']], support:20
# pattern:[['14177.0']], support:21
# pattern:[['14196.0']], support:21
# pattern:[['14196.0', '30248.0']], support:11
# pattern:[['15038.0']], support:21
# pattern:[['30170.0']], support:22
# pattern:[['14160.0']], support:25
# pattern:[['15092.0']], support:34
# pattern:[['15092.0', '15094.0']], support:8
# pattern:[['15092.0', '30248.0']], support:11
# pattern:[['10060.0']], support:49
# pattern:[['10060.0', '30248.0']], support:11
# pattern:[['15009.0']], support:53
# pattern:[['15009.0', '15094.0']], support:8
# pattern:[['15009.0', '15631.0']], support:8
# pattern:[['15009.0', '30248.0']], support:11
# pattern:[['10086.0']], support:55
# pattern:[['10086.0', '30248.0']], support:19
# pattern:[['15631.0']], support:89
# pattern:[['15631.0', '30248.0']], support:26
# pattern:[['15039.0']], support:91
# pattern:[['15039.0', '15052.0']], support:12
# pattern:[['15039.0', '15094.0']], support:13
# pattern:[['15039.0', '30248.0']], support:29
# pattern:[['15012.0']], support:107
# pattern:[['15012.0', '15052.0']], support:8
# pattern:[['15012.0', '15631.0']], support:9
# pattern:[['15012.0', '15039.0']], support:12
# pattern:[['15012.0', '15094.0']], support:14
# pattern:[['15012.0', '30248.0']], support:28
# pattern:[['15052.0']], support:116
# pattern:[['15052.0', '15094.0']], support:24
# pattern:[['15052.0', '15094.0', '30248.0']], support:9
# pattern:[['15052.0', '30248.0']], support:28
# pattern:[['15094.0']], support:122
# pattern:[['15094.0', '15631.0']], support:10
# pattern:[['15094.0', '30248.0']], support:34
# pattern:[['30248.0']], support:251
#
# min_support = 16:
# pattern:[['14051.0']], support:16
# pattern:[['10007.0']], support:17
# pattern:[['15060.0']], support:17
# pattern:[['15590.0']], support:17
# pattern:[['10106.0']], support:17
# pattern:[['14362.0']], support:17
# pattern:[['14265.0']], support:17
# pattern:[['14622.0']], support:18
# pattern:[['14810.0']], support:20
# pattern:[['14177.0']], support:21
# pattern:[['14196.0']], support:21
# pattern:[['15038.0']], support:21
# pattern:[['30170.0']], support:22
# pattern:[['14160.0']], support:25
# pattern:[['15092.0']], support:34
# pattern:[['10060.0']], support:49
# pattern:[['15009.0']], support:53
# pattern:[['10086.0']], support:55
# pattern:[['10086.0', '30248.0']], support:19
# pattern:[['15631.0']], support:89
# pattern:[['15631.0', '30248.0']], support:26
# pattern:[['15039.0']], support:91
# pattern:[['15039.0', '30248.0']], support:29
# pattern:[['15012.0']], support:107
# pattern:[['15012.0', '30248.0']], support:28
# pattern:[['15052.0']], support:116
# pattern:[['15052.0', '15094.0']], support:24
# pattern:[['15052.0', '30248.0']], support:28
# pattern:[['15094.0']], support:122
# pattern:[['15094.0', '30248.0']], support:34
# pattern:[['30248.0']], support:251
#
# min_support = 32:
# pattern:[['15092.0']], support:34
# pattern:[['10060.0']], support:49
# pattern:[['15009.0']], support:53
# pattern:[['10086.0']], support:55
# pattern:[['15631.0']], support:89
# pattern:[['15039.0']], support:91
# pattern:[['15012.0']], support:107
# pattern:[['15052.0']], support:116
# pattern:[['15094.0']], support:122
# pattern:[['15094.0', '30248.0']], support:34
# pattern:[['30248.0']], support:251
#
# min_support = 64:
# pattern:[['15631.0']], support:89
# pattern:[['15039.0']], support:91
# pattern:[['15012.0']], support:107
# pattern:[['15052.0']], support:116
# pattern:[['15094.0']], support:122
# pattern:[['30248.0']], support:251
# min_support = 2:
# pattern:[['10679.0']], support:2
# pattern:[['14179.0']], support:2
# pattern:[['14179.0', '30248.0']], support:2
# pattern:[['14307.0']], support:2
# pattern:[['30750.0']], support:2
# pattern:[['30049.0']], support:2
# pattern:[['30059.0']], support:2
# pattern:[['14826.0']], support:2
# pattern:[['10198.0']], support:2
# pattern:[['11345.0']], support:2
# pattern:[['14070.0']], support:2
# pattern:[['14746.0']], support:2
# ...
# pattern:[['15094.0', '15123.0']], support:4
# pattern:[['15094.0', '15590.0']], support:5
# pattern:[['15094.0', '30170.0']], support:6
# pattern:[['15094.0', '30170.0', '30248.0']], support:5
# pattern:[['15094.0', '15631.0']], support:19
# pattern:[['15094.0', '15631.0', '30248.0']], support:7
# pattern:[['15094.0', '30248.0']], support:88
# pattern:[['30248.0']], support:633
# pattern:[['30248.0', '30262.0']], support:4
# pattern:[['30248.0', '30833.0']], support:5
# pattern:[['30248.0', '31027.0']], support:5
# pattern:[['30248.0', '32133.0']], support:6
#
# min_support = 8:
# pattern:[['14167.0']], support:8
# pattern:[['14121.0']], support:8
# pattern:[['11094.0']], support:8
# pattern:[['11327.0']], support:8
# pattern:[['14752.0']], support:8
# pattern:[['14110.0']], support:8
# pattern:[['11106.0']], support:8
# pattern:[['14067.0']], support:8
# pattern:[['14444.0']], support:8
# pattern:[['10161.0']], support:8
# pattern:[['14245.0']], support:8
# pattern:[['15632.0']], support:8
# pattern:[['14395.0']], support:8
# pattern:[['14652.0']], support:8
# pattern:[['14145.0']], support:9
# pattern:[['14445.0']], support:9
# pattern:[['11123.0']], support:9
# pattern:[['11224.0']], support:9
# pattern:[['14357.0']], support:9
# pattern:[['14443.0']], support:9
# pattern:[['10199.0']], support:9
# pattern:[['15074.0']], support:9
# pattern:[['10652.0']], support:9
# pattern:[['14651.0']], support:9
# pattern:[['31027.0']], support:9
# pattern:[['14102.0']], support:9
# pattern:[['14152.0']], support:9
# pattern:[['14440.0']], support:9
# pattern:[['14440.0', '30248.0']], support:8
# pattern:[['14071.0']], support:9
# pattern:[['30192.0']], support:9
# pattern:[['14267.0']], support:9
# pattern:[['30017.0']], support:9
# pattern:[['10632.0']], support:9
# pattern:[['14544.0']], support:9
# pattern:[['14449.0']], support:10
# pattern:[['30727.0']], support:10
# pattern:[['14008.0']], support:10
# pattern:[['15653.0']], support:10
# pattern:[['14509.0']], support:10
# pattern:[['15078.0']], support:10
# pattern:[['11079.0']], support:10
# pattern:[['14041.0']], support:10
# pattern:[['14189.0']], support:10
# pattern:[['15577.0']], support:10
# pattern:[['30216.0']], support:11
# pattern:[['14301.0']], support:11
# pattern:[['14200.0']], support:11
# pattern:[['14126.0']], support:11
# pattern:[['14573.0']], support:11
# pattern:[['14035.0']], support:11
# pattern:[['14460.0']], support:11
# pattern:[['14372.0']], support:11
# pattern:[['11036.0']], support:11
# pattern:[['10091.0']], support:12
# pattern:[['14740.0']], support:12
# pattern:[['14740.0', '30248.0']], support:8
# pattern:[['14805.0']], support:12
# pattern:[['10124.0']], support:12
# pattern:[['10033.0']], support:12
# pattern:[['31017.0']], support:12
# pattern:[['11154.0']], support:12
# pattern:[['14224.0']], support:12
# pattern:[['14333.0']], support:12
# pattern:[['14112.0']], support:12
# pattern:[['14386.0']], support:12
# pattern:[['14799.0']], support:12
# pattern:[['14191.0']], support:12
# pattern:[['32133.0']], support:13
# pattern:[['10163.0']], support:13
# pattern:[['14354.0']], support:13
# pattern:[['11159.0']], support:13
# pattern:[['14123.0']], support:14
# pattern:[['14545.0']], support:14
# pattern:[['14231.0']], support:14
# pattern:[['15001.0']], support:14
# pattern:[['14213.0']], support:14
# pattern:[['15002.0']], support:15
# pattern:[['11114.0']], support:15
# pattern:[['34214.0']], support:15
# pattern:[['15073.0']], support:15
# pattern:[['14435.0']], support:15
# pattern:[['30833.0']], support:16
# pattern:[['14079.0']], support:16
# pattern:[['14079.0', '30248.0']], support:8
# pattern:[['14345.0']], support:16
# pattern:[['14345.0', '30248.0']], support:8
# pattern:[['10045.0']], support:16
# pattern:[['10094.0']], support:16
# pattern:[['10064.0']], support:16
# pattern:[['15057.0']], support:16
# pattern:[['15057.0', '30248.0']], support:9
# pattern:[['10659.0']], support:16
# pattern:[['14208.0']], support:17
# pattern:[['14208.0', '30248.0']], support:10
# pattern:[['11026.0']], support:17
# pattern:[['14032.0']], support:18
# pattern:[['14032.0', '30248.0']], support:12
# pattern:[['14258.0']], support:18
# pattern:[['14258.0', '30248.0']], support:9
# pattern:[['10069.0']], support:19
# pattern:[['10069.0', '30248.0']], support:9
# pattern:[['14225.0']], support:19
# pattern:[['14044.0']], support:20
# pattern:[['14082.0']], support:20
# pattern:[['14082.0', '30248.0']], support:12
# pattern:[['14455.0']], support:20
# pattern:[['14455.0', '30248.0']], support:13
# pattern:[['14051.0']], support:20
# pattern:[['14051.0', '30248.0']], support:9
# pattern:[['14338.0']], support:21
# pattern:[['14338.0', '30248.0']], support:13
# pattern:[['10080.0']], support:22
# pattern:[['10080.0', '30248.0']], support:9
# pattern:[['15123.0']], support:22
# pattern:[['10211.0']], support:23
# pattern:[['10211.0', '30248.0']], support:12
# pattern:[['14362.0']], support:23
# pattern:[['14362.0', '30248.0']], support:11
# pattern:[['11385.0']], support:24
# pattern:[['11385.0', '30248.0']], support:13
# pattern:[['10107.0']], support:24
# pattern:[['15067.0']], support:24
# pattern:[['15026.0']], support:25
# pattern:[['14168.0']], support:25
# pattern:[['14168.0', '30248.0']], support:15
# pattern:[['14173.0']], support:25
# pattern:[['14173.0', '30248.0']], support:8
# pattern:[['15083.0']], support:26
# pattern:[['15083.0', '30248.0']], support:12
# pattern:[['14313.0']], support:26
# pattern:[['14313.0', '30248.0']], support:13
# pattern:[['14330.0']], support:26
# pattern:[['14330.0', '30248.0']], support:14
# pattern:[['10068.0']], support:26
# pattern:[['10068.0', '30248.0']], support:8
# pattern:[['14268.0']], support:26
# pattern:[['14268.0', '30248.0']], support:8
# pattern:[['14678.0']], support:26
# pattern:[['14678.0', '15094.0']], support:8
# pattern:[['14678.0', '30248.0']], support:13
# pattern:[['14794.0']], support:27
# pattern:[['14794.0', '30248.0']], support:14
# pattern:[['15590.0']], support:28
# pattern:[['15590.0', '30248.0']], support:12
# pattern:[['14265.0']], support:28
# pattern:[['14265.0', '30248.0']], support:8
# pattern:[['14319.0']], support:29
# pattern:[['14319.0', '30248.0']], support:8
# pattern:[['11129.0']], support:29
# pattern:[['11129.0', '30248.0']], support:9
# pattern:[['15011.0']], support:29
# pattern:[['15011.0', '30248.0']], support:10
# pattern:[['10106.0']], support:31
# pattern:[['10106.0', '30248.0']], support:11
# pattern:[['10007.0']], support:31
# pattern:[['10007.0', '30248.0']], support:11
# pattern:[['10062.0']], support:31
# pattern:[['10062.0', '30248.0']], support:13
# pattern:[['14160.0']], support:32
# pattern:[['14160.0', '30248.0']], support:11
# pattern:[['15038.0']], support:34
# pattern:[['15038.0', '30248.0']], support:14
# pattern:[['15060.0']], support:35
# pattern:[['15060.0', '30248.0']], support:13
# pattern:[['15045.0']], support:35
# pattern:[['15045.0', '30248.0']], support:13
# pattern:[['14281.0']], support:37
# pattern:[['14281.0', '15094.0']], support:9
# pattern:[['14281.0', '14442.0']], support:10
# pattern:[['14281.0', '30248.0']], support:18
# pattern:[['14810.0']], support:37
# pattern:[['14810.0', '30248.0']], support:8
# pattern:[['14442.0']], support:39
# pattern:[['14442.0', '15012.0']], support:8
# pattern:[['14442.0', '15094.0']], support:8
# pattern:[['14442.0', '30248.0']], support:26
# pattern:[['14475.0']], support:43
# pattern:[['14475.0', '14622.0']], support:9
# pattern:[['14475.0', '30248.0']], support:25
# pattern:[['30170.0']], support:45
# pattern:[['30170.0', '30248.0']], support:19
# pattern:[['15066.0']], support:46
# pattern:[['15066.0', '30248.0']], support:25
# pattern:[['14366.0']], support:47
# pattern:[['14366.0', '30248.0']], support:16
# pattern:[['14322.0']], support:49
# pattern:[['14322.0', '15012.0']], support:8
# pattern:[['14322.0', '15052.0']], support:9
# pattern:[['14322.0', '15094.0']], support:11
# pattern:[['14322.0', '30248.0']], support:19
# pattern:[['14098.0']], support:56
# pattern:[['14098.0', '30248.0']], support:22
# pattern:[['14196.0']], support:57
# pattern:[['14196.0', '15052.0']], support:9
# pattern:[['14196.0', '15094.0']], support:10
# pattern:[['14196.0', '14442.0']], support:11
# pattern:[['14196.0', '14322.0']], support:11
# pattern:[['14196.0', '14281.0']], support:17
# pattern:[['14196.0', '14281.0', '30248.0']], support:8
# pattern:[['14196.0', '30248.0']], support:30
# pattern:[['14622.0']], support:60
# pattern:[['14622.0', '15012.0']], support:8
# pattern:[['14622.0', '30248.0']], support:32
# pattern:[['10706.0']], support:61
# pattern:[['10706.0', '15094.0']], support:10
# pattern:[['10706.0', '30248.0']], support:36
# pattern:[['14177.0']], support:63
# pattern:[['14177.0', '14442.0']], support:8
# pattern:[['14177.0', '30248.0']], support:27
# pattern:[['10060.0']], support:63
# pattern:[['10060.0', '30248.0']], support:13
# pattern:[['15092.0']], support:73
# pattern:[['15092.0', '15094.0']], support:17
# pattern:[['15092.0', '15094.0', '30248.0']], support:8
# pattern:[['15092.0', '30248.0']], support:32
# pattern:[['10086.0']], support:76
# pattern:[['10086.0', '15094.0']], support:9
# pattern:[['10086.0', '30248.0']], support:20
# pattern:[['15009.0']], support:115
# pattern:[['15009.0', '15092.0']], support:10
# pattern:[['15009.0', '15052.0']], support:11
# pattern:[['15009.0', '15012.0']], support:12
# pattern:[['15009.0', '15094.0']], support:15
# pattern:[['15009.0', '15094.0', '30248.0']], support:10
# pattern:[['15009.0', '15039.0']], support:17
# pattern:[['15009.0', '15039.0', '30248.0']], support:9
# pattern:[['15009.0', '30248.0']], support:42
# pattern:[['15631.0']], support:130
# pattern:[['15631.0', '30248.0']], support:32
# pattern:[['15039.0']], support:133
# pattern:[['15039.0', '15631.0']], support:13
# pattern:[['15039.0', '15052.0']], support:14
# pattern:[['15039.0', '15094.0']], support:19
# pattern:[['15039.0', '15094.0', '30248.0']], support:12
# pattern:[['15039.0', '30248.0']], support:53
# pattern:[['15052.0']], support:170
# pattern:[['15052.0', '15092.0']], support:15
# pattern:[['15052.0', '15092.0', '30248.0']], support:8
# pattern:[['15052.0', '15094.0']], support:27
# pattern:[['15052.0', '15094.0', '30248.0']], support:9
# pattern:[['15052.0', '30248.0']], support:65
# pattern:[['15012.0']], support:215
# pattern:[['15012.0', '15631.0']], support:10
# pattern:[['15012.0', '15052.0']], support:14
# pattern:[['15012.0', '15039.0']], support:16
# pattern:[['15012.0', '15039.0', '30248.0']], support:8
# pattern:[['15012.0', '15094.0']], support:34
# pattern:[['15012.0', '15094.0', '30248.0']], support:17
# pattern:[['15012.0', '30248.0']], support:81
# pattern:[['15094.0']], support:231
# pattern:[['15094.0', '15631.0']], support:19
# pattern:[['15094.0', '30248.0']], support:88
# pattern:[['30248.0']], support:633
#
# min_support = 16:
# pattern:[['30833.0']], support:16
# pattern:[['14079.0']], support:16
# pattern:[['14345.0']], support:16
# pattern:[['10045.0']], support:16
# pattern:[['10094.0']], support:16
# pattern:[['10064.0']], support:16
# pattern:[['15057.0']], support:16
# pattern:[['10659.0']], support:16
# pattern:[['14208.0']], support:17
# pattern:[['11026.0']], support:17
# pattern:[['14032.0']], support:18
# pattern:[['14258.0']], support:18
# pattern:[['10069.0']], support:19
# pattern:[['14225.0']], support:19
# pattern:[['14044.0']], support:20
# pattern:[['14082.0']], support:20
# pattern:[['14455.0']], support:20
# pattern:[['14051.0']], support:20
# pattern:[['14338.0']], support:21
# pattern:[['10080.0']], support:22
# pattern:[['15123.0']], support:22
# pattern:[['10211.0']], support:23
# pattern:[['14362.0']], support:23
# pattern:[['11385.0']], support:24
# pattern:[['10107.0']], support:24
# pattern:[['15067.0']], support:24
# pattern:[['15026.0']], support:25
# pattern:[['14168.0']], support:25
# pattern:[['14173.0']], support:25
# pattern:[['15083.0']], support:26
# pattern:[['14313.0']], support:26
# pattern:[['14330.0']], support:26
# pattern:[['10068.0']], support:26
# pattern:[['14268.0']], support:26
# pattern:[['14678.0']], support:26
# pattern:[['14794.0']], support:27
# pattern:[['15590.0']], support:28
# pattern:[['14265.0']], support:28
# pattern:[['14319.0']], support:29
# pattern:[['11129.0']], support:29
# pattern:[['15011.0']], support:29
# pattern:[['10106.0']], support:31
# pattern:[['10007.0']], support:31
# pattern:[['10062.0']], support:31
# pattern:[['14160.0']], support:32
# pattern:[['15038.0']], support:34
# pattern:[['15060.0']], support:35
# pattern:[['15045.0']], support:35
# pattern:[['14281.0']], support:37
# pattern:[['14281.0', '30248.0']], support:18
# pattern:[['14810.0']], support:37
# pattern:[['14442.0']], support:39
# pattern:[['14442.0', '30248.0']], support:26
# pattern:[['14475.0']], support:43
# pattern:[['14475.0', '30248.0']], support:25
# pattern:[['30170.0']], support:45
# pattern:[['30170.0', '30248.0']], support:19
# pattern:[['15066.0']], support:46
# pattern:[['15066.0', '30248.0']], support:25
# pattern:[['14366.0']], support:47
# pattern:[['14366.0', '30248.0']], support:16
# pattern:[['14322.0']], support:49
# pattern:[['14322.0', '30248.0']], support:19
# pattern:[['14098.0']], support:56
# pattern:[['14098.0', '30248.0']], support:22
# pattern:[['14196.0']], support:57
# pattern:[['14196.0', '14281.0']], support:17
# pattern:[['14196.0', '30248.0']], support:30
# pattern:[['14622.0']], support:60
# pattern:[['14622.0', '30248.0']], support:32
# pattern:[['10706.0']], support:61
# pattern:[['10706.0', '30248.0']], support:36
# pattern:[['14177.0']], support:63
# pattern:[['14177.0', '30248.0']], support:27
# pattern:[['10060.0']], support:63
# pattern:[['15092.0']], support:73
# pattern:[['15092.0', '15094.0']], support:17
# pattern:[['15092.0', '30248.0']], support:32
# pattern:[['10086.0']], support:76
# pattern:[['10086.0', '30248.0']], support:20
# pattern:[['15009.0']], support:115
# pattern:[['15009.0', '15039.0']], support:17
# pattern:[['15009.0', '30248.0']], support:42
# pattern:[['15631.0']], support:130
# pattern:[['15631.0', '30248.0']], support:32
# pattern:[['15039.0']], support:133
# pattern:[['15039.0', '15094.0']], support:19
# pattern:[['15039.0', '30248.0']], support:53
# pattern:[['15052.0']], support:170
# pattern:[['15052.0', '15094.0']], support:27
# pattern:[['15052.0', '30248.0']], support:65
# pattern:[['15012.0']], support:215
# pattern:[['15012.0', '15039.0']], support:16
# pattern:[['15012.0', '15094.0']], support:34
# pattern:[['15012.0', '15094.0', '30248.0']], support:17
# pattern:[['15012.0', '30248.0']], support:81
# pattern:[['15094.0']], support:231
# pattern:[['15094.0', '15631.0']], support:19
# pattern:[['15094.0', '30248.0']], support:88
# pattern:[['30248.0']], support:633
#
# min_support = 32:
# pattern:[['14160.0']], support:32
# pattern:[['15038.0']], support:34
# pattern:[['15060.0']], support:35
# pattern:[['15045.0']], support:35
# pattern:[['14281.0']], support:37
# pattern:[['14810.0']], support:37
# pattern:[['14442.0']], support:39
# pattern:[['14475.0']], support:43
# pattern:[['30170.0']], support:45
# pattern:[['15066.0']], support:46
# pattern:[['14366.0']], support:47
# pattern:[['14322.0']], support:49
# pattern:[['14098.0']], support:56
# pattern:[['14196.0']], support:57
# pattern:[['14622.0']], support:60
# pattern:[['14622.0', '30248.0']], support:32
# pattern:[['10706.0']], support:61
# pattern:[['10706.0', '30248.0']], support:36
# pattern:[['14177.0']], support:63
# pattern:[['10060.0']], support:63
# pattern:[['15092.0']], support:73
# pattern:[['15092.0', '30248.0']], support:32
# pattern:[['10086.0']], support:76
# pattern:[['15009.0']], support:115
# pattern:[['15009.0', '30248.0']], support:42
# pattern:[['15631.0']], support:130
# pattern:[['15631.0', '30248.0']], support:32
# pattern:[['15039.0']], support:133
# pattern:[['15039.0', '30248.0']], support:53
# pattern:[['15052.0']], support:170
# pattern:[['15052.0', '30248.0']], support:65
# pattern:[['15012.0']], support:215
# pattern:[['15012.0', '15094.0']], support:34
# pattern:[['15012.0', '30248.0']], support:81
# pattern:[['15094.0']], support:231
# pattern:[['15094.0', '30248.0']], support:88
# pattern:[['30248.0']], support:633
#
# min_support = 64:
# pattern:[['15092.0']], support:73
# pattern:[['10086.0']], support:76
# pattern:[['15009.0']], support:115
# pattern:[['15631.0']], support:130
# pattern:[['15039.0']], support:133
# pattern:[['15052.0']], support:170
# pattern:[['15052.0', '30248.0']], support:65
# pattern:[['15012.0']], support:215
# pattern:[['15012.0', '30248.0']], support:81
# pattern:[['15094.0']], support:231
# pattern:[['15094.0', '30248.0']], support:88
# pattern:[['30248.0']], support:633
